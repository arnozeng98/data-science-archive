# %% [markdown]
# # PostgreSQL
#
# ## Subqueries, window functions, CTEs

# %% [markdown]
# ## Instructions
# ---
# rubric={mechanics:2}

# %% [markdown]
# - Follow the [general lab instructions](https://ubc-mds.github.io/resources_pages/general_lab_instructions/)
#
# - You submit 3 files to Gradescope (***upload it separately, not as a zip file, or folder***)
#     - Fully rendered ipynb notebook,
#     - HTML of the fully rendered ipynb notebook
#     - PDF of the fully rendered ipynb notebook
#
# - We don't have challenging questions in this lab.
# - Add a link to your GitHub repository here: https://github.ubc.ca/mds-2024-25/DSCI_513_lab3_lingsong
#
# > NOTE: There is no autograding for any of our labs. So, the idea of Gradescope is just to upload the 3 files listed above. You just need to make sure that it is uploaded. You must upload 3 files individually to Gradescope (not in a folder or a zipped folder).

# %% [markdown]
# ## Getting set up
# ---

# %%
# %load_ext sql
# %config SqlMagic.displaylimit = 50

import json
import urllib.parse

with open('data/credentials.json') as f:
    login = json.load(f)
    
username = login['user']
password = urllib.parse.quote(login['password'])
host = login['host']
port = login['port']

# %%
username
# Out:
# 'postgres'

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/world

# %% [markdown]
# ## Exercise 1: Simple subqueries
# ---

# %% [markdown]
# ### 1.1
#
# rubric={accuracy:2}

# %% [markdown]
# Suppose that we are interested in computing how far the life expectancy of each country in the `country` table is from its average value for all countries in the world. This can be expressed as `lifeexpectancy` $-$ `AVG(lifeexpectancy)`.
#
# Write a query that lists country names and their life expectancy deviation from the world average.
#
# - Eliminate rows with null values
# - Sort your results in ascending order by the values in the life expectancy deviation column
# - Round the values in the life expectancy deviation column to 1 decimal digit.

# %%
# %%sql
#
# SELECT
#     name AS "Country",
#     ROUND(
#         lifeexpectancy::NUMERIC - (
#             SELECT AVG(lifeexpectancy)::NUMERIC
#             FROM country
#             WHERE lifeexpectancy IS NOT NULL
#         ), 1) AS "Life Expectancy Deviation"
# FROM
#     country
# WHERE
#     lifeexpectancy IS NOT NULL
# ORDER BY
#     "Life Expectancy Deviation" ASC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 222 rows affected.
# [('Zambia', Decimal('-29.3')),
#  ('Mozambique', Decimal('-29.0')),
#  ('Malawi', Decimal('-28.9')),
#  ('Zimbabwe', Decimal('-28.7')),
#  ('Angola', Decimal('-28.2')),
#  ('Botswana', Decimal('-27.2')),
#  ('Rwanda', Decimal('-27.2')),
#  ('Swaziland', Decimal('-26.1')),
#  ('Niger', Decimal('-25.2')),
#  ('Namibia', Decimal('-24.0')),
#  ('Uganda', Decimal('-23.6')),
#  ('Central African Republic', Decimal('-22.5')),
#  ('Côte d\x92Ivoire', Decimal('-21.3')),
#  ('Ethiopia', Decimal('-21.3')),
#  ('Sierra Leone', Decimal('-21.2')),
#  ('Guinea', Decimal('-20.9')),
#  ('Afghanistan', Decimal('-20.6')),
#  ('East Timor', Decimal('-20.5')),
#  ('Somalia', Decimal('-20.3')),
#  ('Burundi', Decimal('-20.3')),
#  ('Burkina Faso', Decimal('-19.8')),
#  ('Mali', Decimal('-19.8')),
#  ('Congo', Decimal('-19.1')),
#  ('Kenya', Decimal('-18.5')),
#  ('Congo, The Democratic Republic of the', Decimal('-17.7')),
#  ('Guinea-Bissau', Decimal('-17.5')),
#  ('Haiti', Decimal('-17.3')),
#  ('Western Sahara', Decimal('-16.7')),
#  ('Gabon', Decimal('-16.4')),
#  ('Benin', Decimal('-16.3')),
#  ('Chad', Decimal('-16.0')),
#  ('Mauritania', Decimal('-15.7')),
#  ('Lesotho', Decimal('-15.7')),
#  ('Djibouti', Decimal('-15.7')),
#  ('Liberia', Decimal('-15.5')),
#  ('South Africa', Decimal('-15.4')),
#  ('Nigeria', Decimal('-14.9')),
#  ('Tanzania', Decimal('-14.2')),
#  ('Bhutan', Decimal('-14.1')),
#  ('Laos', Decimal('-13.4')),
#  ('Gambia', Decimal('-13.3')),
#  ('Equatorial Guinea', Decimal('-12.9')),
#  ('Togo', Decimal('-11.8')),
#  ('Cameroon', Decimal('-11.7')),
#  ('Myanmar', Decimal('-11.6')),
#  ('Madagascar', Decimal('-11.5')),
#  ('Eritrea', Decimal('-10.7')),
#  ('Cambodia', Decimal('-10.0')),
#  ('Sudan', Decimal('-9.9')),
#  ('Ghana', Decimal('-9.1')),
#  ('Nepal', Decimal('-8.7')),
#  ('Mayotte', Decimal('-7.0')),
#  ('Kiribati', Decimal('-6.7')),
#  ('Yemen', Decimal('-6.7')),
#  ('Comoros', Decimal('-6.5')),
#  ('Bangladesh', Decimal('-6.3')),
#  ('Vanuatu', Decimal('-5.9')),
#  ('Nauru', Decimal('-5.7')),
#  ('Turkmenistan', Decimal('-5.6')),
#  ('Pakistan', Decimal('-5.4')),
#  ('Maldives', Decimal('-4.3')),
#  ('Senegal', Decimal('-4.3')),
#  ('India', Decimal('-4.0')),
#  ('Azerbaijan', Decimal('-3.6')),
#  ('Brazil', Decimal('-3.6')),
#  ('Papua New Guinea', Decimal('-3.4')),
#  ('Kazakstan', Decimal('-3.3')),
#  ('Egypt', Decimal('-3.2')),
#  ('Kyrgyzstan', Decimal('-3.1')),
#  ('Bolivia', Decimal('-2.8')),
#  ('Uzbekistan', Decimal('-2.8')),
#  ('Guyana', Decimal('-2.5')),
#  ('Tajikistan', Decimal('-2.4')),
#  ('Grenada', Decimal('-2.0')),
#  ('Moldova', Decimal('-2.0')),
#  ('Georgia', Decimal('-2.0')),
#  ('Sao Tome and Principe', Decimal('-1.2')),
#  ('Marshall Islands', Decimal('-1.0')),
#  ('Ukraine', Decimal('-0.5')),
#  ('Guatemala', Decimal('-0.3')),
#  ('Tuvalu', Decimal('-0.2')),
#  ('Armenia', Decimal('-0.1')),
#  ('Iraq', Decimal('0.0')),
#  ('Russian Federation', Decimal('0.7')),
#  ('Mongolia', Decimal('0.8')),
#  ('Philippines', Decimal('1.0')),
#  ('Saudi Arabia', Decimal('1.3')),
#  ('Tonga', Decimal('1.4')),
#  ('Fiji Islands', Decimal('1.4')),
#  ('Trinidad and Tobago', Decimal('1.5')),
#  ('Indonesia', Decimal('1.5')),
#  ('Belarus', Decimal('1.5')),
#  ('Greenland', Decimal('1.6')),
#  ('Latvia', Decimal('1.9')),
#  ('Syria', Decimal('2.0')),
#  ('Palau', Decimal('2.1')),
#  ('Micronesia, Federated States of', Decimal('2.1')),
#  ('Thailand', Decimal('2.1')),
#  ('Nicaragua', Decimal('2.2')),
#  ('Cape Verde', Decimal('2.4')),
#  ('Morocco', Decimal('2.6')),
#  ('Lithuania', Decimal('2.6')),
#  ('Samoa', Decimal('2.7')),
#  ('Vietnam', Decimal('2.8')),
#  ('Estonia', Decimal('3.0')),
#  ('Algeria', Decimal('3.2')),
#  ('El Salvador', Decimal('3.2')),
#  ('Iran', Decimal('3.2')),
#  ('Romania', Decimal('3.4')),
#  ('Honduras', Decimal('3.4')),
#  ('Peru', Decimal('3.5')),
#  ('Colombia', Decimal('3.8')),
#  ('Seychelles', Decimal('3.9')),
#  ('Antigua and Barbuda', Decimal('4.0')),
#  ('North Korea', Decimal('4.2')),
#  ('Saint Kitts and Nevis', Decimal('4.2')),
#  ('Malaysia', Decimal('4.3')),
#  ('Bulgaria', Decimal('4.4')),
#  ('Belize', Decimal('4.4')),
#  ('Turkey', Decimal('4.5')),
#  ('Mauritius', Decimal('4.5')),
#  ('Cook Islands', Decimal('4.6')),
#  ('Ecuador', Decimal('4.6')),
#  ('Bahamas', Decimal('4.6')),
#  ('Lebanon', Decimal('4.8')),
#  ('Solomon Islands', Decimal('4.8')),
#  ('Palestine', Decimal('4.9')),
#  ('Suriname', Decimal('4.9')),
#  ('Hungary', Decimal('4.9')),
#  ('China', Decimal('4.9')),
#  ('Mexico', Decimal('5.0')),
#  ('Bosnia and Herzegovina', Decimal('5.0')),
#  ('Albania', Decimal('5.1')),
#  ('Oman', Decimal('5.3')),
#  ('Sri Lanka', Decimal('5.3')),
#  ('Saint Vincent and the Grenadines', Decimal('5.8')),
#  ('Saint Lucia', Decimal('5.8')),
#  ('Yugoslavia', Decimal('5.9')),
#  ('Qatar', Decimal('5.9')),
#  ('Réunion', Decimal('6.2')),
#  ('New Caledonia', Decimal('6.3')),
#  ('Barbados', Decimal('6.5')),
#  ('Bahrain', Decimal('6.5')),
#  ('Venezuela', Decimal('6.6')),
#  ('Poland', Decimal('6.7')),
#  ('Dominican Republic', Decimal('6.7')),
#  ('Turks and Caicos Islands', Decimal('6.8')),
#  ('Dominica', Decimal('6.9')),
#  ('Brunei', Decimal('7.1')),
#  ('Tunisia', Decimal('7.2')),
#  ('Croatia', Decimal('7.2')),
#  ('Paraguay', Decimal('7.2')),
#  ('Slovakia', Decimal('7.2')),
#  ('Macedonia', Decimal('7.3')),
#  ('United Arab Emirates', Decimal('7.6')),
#  ('South Korea', Decimal('7.9')),
#  ('Czech Republic', Decimal('8.0')),
#  ('Netherlands Antilles', Decimal('8.2')),
#  ('French Polynesia', Decimal('8.3')),
#  ('Slovenia', Decimal('8.4')),
#  ('American Samoa', Decimal('8.6')),
#  ('Argentina', Decimal('8.6')),
#  ('Uruguay', Decimal('8.7')),
#  ('Jamaica', Decimal('8.7')),
#  ('Virgin Islands, British', Decimal('8.9')),
#  ('Panama', Decimal('9.0')),
#  ('Libyan Arab Jamahiriya', Decimal('9.0')),
#  ('Northern Mariana Islands', Decimal('9.0')),
#  ('Puerto Rico', Decimal('9.1')),
#  ('Chile', Decimal('9.2')),
#  ('Portugal', Decimal('9.3')),
#  ('Costa Rica', Decimal('9.3')),
#  ('Anguilla', Decimal('9.6')),
#  ('French Guiana', Decimal('9.6')),
#  ('Kuwait', Decimal('9.6')),
#  ('Cuba', Decimal('9.7')),
#  ('Taiwan', Decimal('9.9')),
#  ('Denmark', Decimal('10.0')),
#  ('Cyprus', Decimal('10.2')),
#  ('Ireland', Decimal('10.3')),
#  ('Saint Helena', Decimal('10.3')),
#  ('Bermuda', Decimal('10.4')),
#  ('Guadeloupe', Decimal('10.5')),
#  ('United States', Decimal('10.6')),
#  ('Luxembourg', Decimal('10.6')),
#  ('Germany', Decimal('10.9')),
#  ('Finland', Decimal('10.9')),
#  ('Jordan', Decimal('10.9')),
#  ('Saint Pierre and Miquelon', Decimal('11.1')),
#  ('Austria', Decimal('11.2')),
#  ('United Kingdom', Decimal('11.2')),
#  ('New Zealand', Decimal('11.3')),
#  ('Guam', Decimal('11.3')),
#  ('Belgium', Decimal('11.3')),
#  ('Malta', Decimal('11.4')),
#  ('Montserrat', Decimal('11.5')),
#  ('Virgin Islands, U.S.', Decimal('11.6')),
#  ('Martinique', Decimal('11.8')),
#  ('Netherlands', Decimal('11.8')),
#  ('Greece', Decimal('11.9')),
#  ('Faroe Islands', Decimal('11.9')),
#  ('Aruba', Decimal('11.9')),
#  ('Israel', Decimal('12.1')),
#  ('Norway', Decimal('12.2')),
#  ('Spain', Decimal('12.3')),
#  ('Monaco', Decimal('12.3')),
#  ('France', Decimal('12.3')),
#  ('Liechtenstein', Decimal('12.3')),
#  ('Cayman Islands', Decimal('12.4')),
#  ('Gibraltar', Decimal('12.5')),
#  ('Italy', Decimal('12.5')),
#  ('Canada', Decimal('12.9')),
#  ('Iceland', Decimal('12.9')),
#  ('Hong Kong', Decimal('13.0')),
#  ('Switzerland', Decimal('13.1')),
#  ('Sweden', Decimal('13.1')),
#  ('Australia', Decimal('13.3')),
#  ('Singapore', Decimal('13.6')),
#  ('Japan', Decimal('14.2')),
#  ('San Marino', Decimal('14.6')),
#  ('Macao', Decimal('15.1')),
#  ('Andorra', Decimal('17.0'))]

# %% [markdown]
# ### 1.2
#
# rubric={reasoning:1}

# %% [markdown]
# Explain why you can't write a query for Exercise [1.1](#1.1) without using a subquery.

# %% [markdown]
# **Answer:** Because SQL does not allow us to directly mix aggregate functions (such as `AVG()`) and row-level calculations in the same query.

# %% [markdown]
# ### 1.3
#
# rubric={accuracy:2}

# %% [markdown]
# Use your query in Exercise [1.1](#1.1) to return the same columns, but modify it such that only countries are returned whose population density (i.e. `population / surfacearea`) is greater than the world average.
#
# On average, do the countries returned by your query have lower or higher life expectancy, compared to the world average? (No computation needed, just look at the results to find out).

# %% [markdown]
# _Type your answer here, replacing this text._

# %%
# %%sql
#
# SELECT
#     name AS "Country",
#     ROUND(lifeexpectancy::NUMERIC - (
#         SELECT AVG(lifeexpectancy)::NUMERIC
#         FROM country
#         WHERE lifeexpectancy IS NOT NULL
#     ), 1) AS "Life Expectancy Deviation"
# FROM
#     country
# WHERE
#     lifeexpectancy IS NOT NULL
#     AND population / surfacearea > (
#         SELECT AVG(population / surfacearea)
#         FROM country
#         WHERE population IS NOT NULL AND surfacearea IS NOT NULL
#     )
# ORDER BY
#     "Life Expectancy Deviation" ASC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 20 rows affected.
# [('Bangladesh', Decimal('-6.3')),
#  ('Nauru', Decimal('-5.7')),
#  ('Maldives', Decimal('-4.3')),
#  ('Tuvalu', Decimal('-0.2')),
#  ('Mauritius', Decimal('4.5')),
#  ('Palestine', Decimal('4.9')),
#  ('Barbados', Decimal('6.5')),
#  ('Bahrain', Decimal('6.5')),
#  ('South Korea', Decimal('7.9')),
#  ('Puerto Rico', Decimal('9.1')),
#  ('Taiwan', Decimal('9.9')),
#  ('Bermuda', Decimal('10.4')),
#  ('Malta', Decimal('11.4')),
#  ('Aruba', Decimal('11.9')),
#  ('Monaco', Decimal('12.3')),
#  ('Gibraltar', Decimal('12.5')),
#  ('Hong Kong', Decimal('13.0')),
#  ('Singapore', Decimal('13.6')),
#  ('San Marino', Decimal('14.6')),
#  ('Macao', Decimal('15.1'))]

# %% [markdown]
# ### 1.4
#
# rubric={accuracy:2}

# %% [markdown]
# Write a query that lists all continents and the number of countries in each continent that have a life expectancy greater than 77 years. If there are no countries in a continent that satisfy this condition, the value of the second column should be null.
#
# Your result should look like this if ordered alphabetically by continent:
#
# <img src="img/1_4.png" width="170">

# %% [markdown]
# > **Hint:** The result of a subquery is also a table that you can use in a join operation.

# %%
# %%sql
#
# SELECT
#     continents.continent,
#     CASE
#         WHEN "lifeexpectancy > 77".count > 0
#         THEN "lifeexpectancy > 77".count
#         ELSE NULL
#     END AS count
# FROM
#     (SELECT DISTINCT continent FROM country) AS continents
# LEFT JOIN
#     (
#         SELECT
#             continent,
#             COUNT(*) AS count
#         FROM
#             country
#         WHERE
#             lifeexpectancy > 77
#         GROUP BY
#             continent
#     ) AS "lifeexpectancy > 77"
# ON
#     continents.continent = "lifeexpectancy > 77".continent
# ORDER BY
#     continents.continent;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 7 rows affected.
# [('Africa', None),
#  ('Antarctica', None),
#  ('Asia', 6),
#  ('Europe', 22),
#  ('North America', 8),
#  ('Oceania', 3),
#  ('South America', None)]

# %% [markdown]
# ### 1.5
#
# rubric={accuracy:2}

# %% [markdown]
# Retrieve the names of non-European countries in the world where one or more of the official European languages are spoken (either officially or non-officially). Make sure to remove duplicate country names from your results, and sort the rows by country name in descending order.
#
# For this query, I have provided some starter code for you:

# %%
# %%sql
#
# SELECT DISTINCT
#     c.name AS "Country"
# FROM
#     country c
# JOIN
#     countrylanguage cl
# ON
#     c.code = cl.countrycode
# WHERE
#     c.continent != 'Europe'
#     AND
#     cl.language IN (
#         SELECT DISTINCT
#             cl.language
#         FROM
#             country c
#         JOIN
#             countrylanguage cl
#         ON
#             c.code = cl.countrycode
#         WHERE
#             c.continent = 'Europe'
#     )
# ORDER BY
#     "Country" DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 120 rows affected.
# [('Zimbabwe',),
#  ('Yemen',),
#  ('Western Sahara',),
#  ('Virgin Islands, U.S.',),
#  ('Virgin Islands, British',),
#  ('Venezuela',),
#  ('Vanuatu',),
#  ('Uzbekistan',),
#  ('Uruguay',),
#  ('United States Minor Outlying Islands',),
#  ('United States',),
#  ('United Arab Emirates',),
#  ('Tuvalu',),
#  ('Turks and Caicos Islands',),
#  ('Turkmenistan',),
#  ('Turkey',),
#  ('Tunisia',),
#  ('Trinidad and Tobago',),
#  ('Tonga',),
#  ('Tokelau',),
#  ('Tajikistan',),
#  ('Syria',),
#  ('Sudan',),
#  ('South Africa',),
#  ('Somalia',),
#  ('Seychelles',),
#  ('Saudi Arabia',),
#  ('Sao Tome and Principe',),
#  ('Samoa',),
#  ('Saint Vincent and the Grenadines',),
#  ('Saint Pierre and Miquelon',),
#  ('Saint Lucia',),
#  ('Saint Kitts and Nevis',),
#  ('Saint Helena',),
#  ('Rwanda',),
#  ('Qatar',),
#  ('Puerto Rico',),
#  ('Peru',),
#  ('Paraguay',),
#  ('Panama',),
#  ('Palestine',),
#  ('Palau',),
#  ('Oman',),
#  ('Northern Mariana Islands',),
#  ('Norfolk Island',),
#  ('Niue',),
#  ('Nicaragua',),
#  ('New Zealand',),
#  ('New Caledonia',),
#  ('Netherlands Antilles',),
#  ('Nauru',),
#  ('Namibia',),
#  ('Morocco',),
#  ('Montserrat',),
#  ('Mongolia',),
#  ('Mexico',),
#  ('Mayotte',),
#  ('Mauritius',),
#  ('Martinique',),
#  ('Marshall Islands',),
#  ('Maldives',),
#  ('Malaysia',),
#  ('Madagascar',),
#  ('Macao',),
#  ('Libyan Arab Jamahiriya',),
#  ('Lesotho',),
#  ('Lebanon',),
#  ('Kyrgyzstan',),
#  ('Kuwait',),
#  ('Kazakstan',),
#  ('Jordan',),
#  ('Japan',),
#  ('Israel',),
#  ('Iraq',),
#  ('Iran',),
#  ('Hong Kong',),
#  ('Honduras',),
#  ('Haiti',),
#  ('Guinea-Bissau',),
#  ('Guatemala',),
#  ('Guam',),
#  ('Guadeloupe',),
#  ('Greenland',),
#  ('Georgia',),
#  ('French Polynesia',),
#  ('Falkland Islands',),
#  ('El Salvador',),
#  ('Egypt',),
#  ('Ecuador',),
#  ('East Timor',),
#  ('Dominican Republic',),
#  ('Djibouti',),
#  ('Cyprus',),
#  ('Cuba',),
#  ('Costa Rica',),
#  ('Cook Islands',),
#  ('Colombia',),
#  ('Cocos (Keeling) Islands',),
#  ('Christmas Island',),
#  ('Chile',),
#  ('Chad',),
#  ('Cayman Islands',),
#  ('Cape Verde',),
#  ('Canada',),
#  ('Burundi',),
#  ('Brunei',),
#  ('Brazil',),
#  ('Bolivia',),
#  ('Bermuda',),
#  ('Belize',),
#  ('Barbados',),
#  ('Bahrain',),
#  ('Azerbaijan',),
#  ('Australia',),
#  ('Aruba',),
#  ('Argentina',),
#  ('Antigua and Barbuda',),
#  ('Anguilla',),
#  ('American Samoa',),
#  ('Algeria',)]

# %% [markdown]
# ### 1.6
#
# rubric={accuracy:2}

# %% [markdown]
# Rewrite the following query using a subquery instead of a join:
#
# ```sql
# SELECT
#     c.name
# FROM
#     country c
# JOIN
#     city ci
# ON
#     c.capital = ci.id
# WHERE
#     ci.population > 5000000
# ;
# ```

# %%
# %%sql
#
# SELECT name
# FROM country
# WHERE
#     capital IN (
#         SELECT id
#         FROM city
#         WHERE population > 5000000
#     );
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 13 rows affected.
# [('United Kingdom',),
#  ('Egypt',),
#  ('Indonesia',),
#  ('Iran',),
#  ('Japan',),
#  ('China',),
#  ('Colombia',),
#  ('Congo, The Democratic Republic of the',),
#  ('South Korea',),
#  ('Mexico',),
#  ('Peru',),
#  ('Thailand',),
#  ('Russian Federation',)]

# %% [markdown]
# ### 1.7
#
# rubric={accuracy:2}

# %% [markdown]
# Which countries in the world are vast enough that all western European and Nordic countries could fit within them?

# %%
# %%sql
#
# SELECT
#     name AS "Country",
#     surfacearea AS "Surface Area"
# FROM
#     country
# WHERE
#     surfacearea > (
#         SELECT SUM(surfacearea)
#         FROM country
#         WHERE region IN ('Western Europe', 'Nordic Countries')
#     )
# ORDER BY
#     surfacearea DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 11 rows affected.
# [('Russian Federation', 17075400.0),
#  ('Antarctica', 13120000.0),
#  ('Canada', 9970610.0),
#  ('China', 9572900.0),
#  ('United States', 9363520.0),
#  ('Brazil', 8547403.0),
#  ('Australia', 7741220.0),
#  ('India', 3287263.0),
#  ('Argentina', 2780400.0),
#  ('Kazakstan', 2724900.0),
#  ('Sudan', 2505813.0)]

# %% [markdown]
# ## Exercise 2: Correlated subqueries
# ---

# %% [markdown]
# ### 2.1
#
# rubric={accuracy:3}

# %% [markdown]
# Find the number of countries in each continent whose life expectancy is greater than the average value for their respective continent.
#
# > **Hint:** The `lifeexpectancy` column contains a bunch of nulls. Be careful with your counting!
#
# > "Antarctica" won't be there in the final result.

# %%
# %%sql
#
# SELECT
#     continent AS "Continent",
#     COUNT(*) AS "Number of Countries have Life Expectancy Above Average"
# FROM
#     country
# WHERE
#     lifeexpectancy IS NOT NULL
#     AND lifeexpectancy > (
#         SELECT AVG(lifeexpectancy)
#         FROM country AS subquery
#         WHERE lifeexpectancy IS NOT NULL
#         AND subquery.continent = country.continent
#     )
# GROUP BY
#     "Continent"
# ORDER BY
#     "Number of Countries have Life Expectancy Above Average" DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 6 rows affected.
# [('Asia', 29),
#  ('Europe', 25),
#  ('Africa', 22),
#  ('North America', 22),
#  ('Oceania', 9),
#  ('South America', 8)]

# %% [markdown]
# ### 2.2
#
# rubric={accuracy:2}

# %% [markdown]
# The results of your query for the previous question may not be very informative on first look, because absolute counts do not reveal much unless we can relate them to the total number of countries in each continent.
#
# Borrow your query from Exercise [2.1](#2.2) and modify it such that it shows the ratio of the number of countries in each continent whose life expectancy is greater than their continent-average values, to the total number of countries in each continent. Round your ratio values to 2 decimal digits.
#
# > **Hint:** Again, be careful with your counting, since `lifeexpectancy` column contains a bunch of nulls, and we don't want to include NULLS.
#
# > **Hint:** That's right, you need to add one more subquery somewhere in your previous query!

# %%
# %%sql
#
# SELECT
#     continent AS "Continent",
#     ROUND(
#         COUNT(*)::NUMERIC / (
#             SELECT COUNT(*)::NUMERIC
#             FROM country AS subquery_total
#             WHERE subquery_total.continent = country.continent
#             AND lifeexpectancy IS NOT NULL
#         ), 2) AS "Ratio of Countries Above Average"
# FROM
#     country
# WHERE
#     lifeexpectancy IS NOT NULL
#     AND lifeexpectancy > (
#         SELECT AVG(lifeexpectancy)
#         FROM country AS subquery_avg
#         WHERE subquery_avg.continent = country.continent
#         AND lifeexpectancy IS NOT NULL
#     )
# GROUP BY
#     continent
# ORDER BY
#     "Ratio of Countries Above Average" DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 6 rows affected.
# [('South America', Decimal('0.62')),
#  ('North America', Decimal('0.59')),
#  ('Asia', Decimal('0.57')),
#  ('Europe', Decimal('0.57')),
#  ('Oceania', Decimal('0.45')),
#  ('Africa', Decimal('0.39'))]

# %% [markdown]
# ### 2.3
#
# rubric={reasoning:2}

# %% [markdown]
# Consider this question:
#
# In which European countries English is **not** spoken at all (i.e. not listed in the `countrylanguage` table)?
#
# I have written the following SQL query to answer the above question:
#
# ```sql
# SELECT
#     DISTINCT c.name
# FROM
#     country c
# JOIN
#     countrylanguage cl
# ON
#     c.code = cl.countrycode
# WHERE
#     NOT cl.language ILIKE 'english'
#     AND
#     c.continent ILIKE 'europe'
# ;
# ```
#
# However, when I run the above query I can find "United Kingdom" listed in the results, which is clearly incorrect. Can you tell me why I'm getting wrong results?

# %% [markdown]
# **Answer:**
#
# The problem lies in the query logic. `NOT cl.language ILIKE 'english'` only filters records of a single language, but does not exclude the entire country. If a country has multiple languages, languages ​​other than "English" will still appear in the results, such as the United Kingdom. The correct approach is to use a subquery to find all the country codes that speak "English", and then exclude these countries in the main query to ensure that the results do not include any countries that speak "English".

# %% [markdown]
# ### 2.4
#
# rubric={accuracy:2}

# %% [markdown]
# Alright, let's figure out how to correctly answer the following question from Exercise [2.3](#2.3):
#
# In which European countries English is **not** spoken at all (i.e. not listed in the `countrylanguage` table)?
#
# **Note:** There's more than one way to answer the above question using a query. Here, I want you to use a correlated subquery.

# %%
# %%sql
#
# SELECT
#     c.name AS "Country"
# FROM
#     country c
# WHERE
#     c.continent ILIKE 'europe'
#     AND NOT EXISTS (
#         SELECT 1
#         FROM countrylanguage cl
#         WHERE cl.countrycode = c.code
#         AND cl.language ILIKE 'english'
#     );
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 38 rows affected.
# [('Switzerland',),
#  ('France',),
#  ('Luxembourg',),
#  ('Czech Republic',),
#  ('Holy See (Vatican City State)',),
#  ('Moldova',),
#  ('Ukraine',),
#  ('Faroe Islands',),
#  ('Svalbard and Jan Mayen',),
#  ('Andorra',),
#  ('Liechtenstein',),
#  ('Croatia',),
#  ('Netherlands',),
#  ('Hungary',),
#  ('Portugal',),
#  ('Greece',),
#  ('Belarus',),
#  ('Lithuania',),
#  ('Spain',),
#  ('Bosnia and Herzegovina',),
#  ('Germany',),
#  ('Bulgaria',),
#  ('Austria',),
#  ('Latvia',),
#  ('Italy',),
#  ('Romania',),
#  ('Macedonia',),
#  ('Estonia',),
#  ('Poland',),
#  ('Russian Federation',),
#  ('Finland',),
#  ('San Marino',),
#  ('Slovakia',),
#  ('Slovenia',),
#  ('Albania',),
#  ('Belgium',),
#  ('Yugoslavia',),
#  ('Sweden',)]

# %% [markdown]
# ## Exercise 3: Window functions and CTEs
# ---

# %% [markdown]
# ### 3.1
#
# rubric={accuracy:1}

# %% [markdown]
# Rewrite the query that you've written for Exercise [1.1](#1.1) using window functions this time.

# %%
# %%sql
#
# SELECT
#     name AS "Country",
#     ROUND(
#         lifeexpectancy::NUMERIC - AVG(lifeexpectancy) OVER ()::NUMERIC, 1
#     ) AS "Life Expectancy Deviation"
# FROM
#     country
# WHERE
#     lifeexpectancy IS NOT NULL
# ORDER BY
#     "Life Expectancy Deviation" ASC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 222 rows affected.
# [('Zambia', Decimal('-29.3')),
#  ('Mozambique', Decimal('-29.0')),
#  ('Malawi', Decimal('-28.9')),
#  ('Zimbabwe', Decimal('-28.7')),
#  ('Angola', Decimal('-28.2')),
#  ('Botswana', Decimal('-27.2')),
#  ('Rwanda', Decimal('-27.2')),
#  ('Swaziland', Decimal('-26.1')),
#  ('Niger', Decimal('-25.2')),
#  ('Namibia', Decimal('-24.0')),
#  ('Uganda', Decimal('-23.6')),
#  ('Central African Republic', Decimal('-22.5')),
#  ('Côte d\x92Ivoire', Decimal('-21.3')),
#  ('Ethiopia', Decimal('-21.3')),
#  ('Sierra Leone', Decimal('-21.2')),
#  ('Guinea', Decimal('-20.9')),
#  ('Afghanistan', Decimal('-20.6')),
#  ('East Timor', Decimal('-20.5')),
#  ('Somalia', Decimal('-20.3')),
#  ('Burundi', Decimal('-20.3')),
#  ('Burkina Faso', Decimal('-19.8')),
#  ('Mali', Decimal('-19.8')),
#  ('Congo', Decimal('-19.1')),
#  ('Kenya', Decimal('-18.5')),
#  ('Congo, The Democratic Republic of the', Decimal('-17.7')),
#  ('Guinea-Bissau', Decimal('-17.5')),
#  ('Haiti', Decimal('-17.3')),
#  ('Western Sahara', Decimal('-16.7')),
#  ('Gabon', Decimal('-16.4')),
#  ('Benin', Decimal('-16.3')),
#  ('Chad', Decimal('-16.0')),
#  ('Mauritania', Decimal('-15.7')),
#  ('Lesotho', Decimal('-15.7')),
#  ('Djibouti', Decimal('-15.7')),
#  ('Liberia', Decimal('-15.5')),
#  ('South Africa', Decimal('-15.4')),
#  ('Nigeria', Decimal('-14.9')),
#  ('Tanzania', Decimal('-14.2')),
#  ('Bhutan', Decimal('-14.1')),
#  ('Laos', Decimal('-13.4')),
#  ('Gambia', Decimal('-13.3')),
#  ('Equatorial Guinea', Decimal('-12.9')),
#  ('Togo', Decimal('-11.8')),
#  ('Cameroon', Decimal('-11.7')),
#  ('Myanmar', Decimal('-11.6')),
#  ('Madagascar', Decimal('-11.5')),
#  ('Eritrea', Decimal('-10.7')),
#  ('Cambodia', Decimal('-10.0')),
#  ('Sudan', Decimal('-9.9')),
#  ('Ghana', Decimal('-9.1')),
#  ('Nepal', Decimal('-8.7')),
#  ('Mayotte', Decimal('-7.0')),
#  ('Kiribati', Decimal('-6.7')),
#  ('Yemen', Decimal('-6.7')),
#  ('Comoros', Decimal('-6.5')),
#  ('Bangladesh', Decimal('-6.3')),
#  ('Vanuatu', Decimal('-5.9')),
#  ('Nauru', Decimal('-5.7')),
#  ('Turkmenistan', Decimal('-5.6')),
#  ('Pakistan', Decimal('-5.4')),
#  ('Maldives', Decimal('-4.3')),
#  ('Senegal', Decimal('-4.3')),
#  ('India', Decimal('-4.0')),
#  ('Azerbaijan', Decimal('-3.6')),
#  ('Brazil', Decimal('-3.6')),
#  ('Papua New Guinea', Decimal('-3.4')),
#  ('Kazakstan', Decimal('-3.3')),
#  ('Egypt', Decimal('-3.2')),
#  ('Kyrgyzstan', Decimal('-3.1')),
#  ('Bolivia', Decimal('-2.8')),
#  ('Uzbekistan', Decimal('-2.8')),
#  ('Guyana', Decimal('-2.5')),
#  ('Tajikistan', Decimal('-2.4')),
#  ('Grenada', Decimal('-2.0')),
#  ('Moldova', Decimal('-2.0')),
#  ('Georgia', Decimal('-2.0')),
#  ('Sao Tome and Principe', Decimal('-1.2')),
#  ('Marshall Islands', Decimal('-1.0')),
#  ('Ukraine', Decimal('-0.5')),
#  ('Guatemala', Decimal('-0.3')),
#  ('Tuvalu', Decimal('-0.2')),
#  ('Armenia', Decimal('-0.1')),
#  ('Iraq', Decimal('0.0')),
#  ('Russian Federation', Decimal('0.7')),
#  ('Mongolia', Decimal('0.8')),
#  ('Philippines', Decimal('1.0')),
#  ('Saudi Arabia', Decimal('1.3')),
#  ('Tonga', Decimal('1.4')),
#  ('Fiji Islands', Decimal('1.4')),
#  ('Trinidad and Tobago', Decimal('1.5')),
#  ('Indonesia', Decimal('1.5')),
#  ('Belarus', Decimal('1.5')),
#  ('Greenland', Decimal('1.6')),
#  ('Latvia', Decimal('1.9')),
#  ('Syria', Decimal('2.0')),
#  ('Palau', Decimal('2.1')),
#  ('Micronesia, Federated States of', Decimal('2.1')),
#  ('Thailand', Decimal('2.1')),
#  ('Nicaragua', Decimal('2.2')),
#  ('Cape Verde', Decimal('2.4')),
#  ('Morocco', Decimal('2.6')),
#  ('Lithuania', Decimal('2.6')),
#  ('Samoa', Decimal('2.7')),
#  ('Vietnam', Decimal('2.8')),
#  ('Estonia', Decimal('3.0')),
#  ('Algeria', Decimal('3.2')),
#  ('El Salvador', Decimal('3.2')),
#  ('Iran', Decimal('3.2')),
#  ('Romania', Decimal('3.4')),
#  ('Honduras', Decimal('3.4')),
#  ('Peru', Decimal('3.5')),
#  ('Colombia', Decimal('3.8')),
#  ('Seychelles', Decimal('3.9')),
#  ('Antigua and Barbuda', Decimal('4.0')),
#  ('North Korea', Decimal('4.2')),
#  ('Saint Kitts and Nevis', Decimal('4.2')),
#  ('Malaysia', Decimal('4.3')),
#  ('Bulgaria', Decimal('4.4')),
#  ('Belize', Decimal('4.4')),
#  ('Turkey', Decimal('4.5')),
#  ('Mauritius', Decimal('4.5')),
#  ('Cook Islands', Decimal('4.6')),
#  ('Ecuador', Decimal('4.6')),
#  ('Bahamas', Decimal('4.6')),
#  ('Lebanon', Decimal('4.8')),
#  ('Solomon Islands', Decimal('4.8')),
#  ('Palestine', Decimal('4.9')),
#  ('Suriname', Decimal('4.9')),
#  ('Hungary', Decimal('4.9')),
#  ('China', Decimal('4.9')),
#  ('Mexico', Decimal('5.0')),
#  ('Bosnia and Herzegovina', Decimal('5.0')),
#  ('Albania', Decimal('5.1')),
#  ('Oman', Decimal('5.3')),
#  ('Sri Lanka', Decimal('5.3')),
#  ('Saint Vincent and the Grenadines', Decimal('5.8')),
#  ('Saint Lucia', Decimal('5.8')),
#  ('Yugoslavia', Decimal('5.9')),
#  ('Qatar', Decimal('5.9')),
#  ('Réunion', Decimal('6.2')),
#  ('New Caledonia', Decimal('6.3')),
#  ('Barbados', Decimal('6.5')),
#  ('Bahrain', Decimal('6.5')),
#  ('Venezuela', Decimal('6.6')),
#  ('Poland', Decimal('6.7')),
#  ('Dominican Republic', Decimal('6.7')),
#  ('Turks and Caicos Islands', Decimal('6.8')),
#  ('Dominica', Decimal('6.9')),
#  ('Brunei', Decimal('7.1')),
#  ('Tunisia', Decimal('7.2')),
#  ('Croatia', Decimal('7.2')),
#  ('Paraguay', Decimal('7.2')),
#  ('Slovakia', Decimal('7.2')),
#  ('Macedonia', Decimal('7.3')),
#  ('United Arab Emirates', Decimal('7.6')),
#  ('South Korea', Decimal('7.9')),
#  ('Czech Republic', Decimal('8.0')),
#  ('Netherlands Antilles', Decimal('8.2')),
#  ('French Polynesia', Decimal('8.3')),
#  ('Slovenia', Decimal('8.4')),
#  ('American Samoa', Decimal('8.6')),
#  ('Argentina', Decimal('8.6')),
#  ('Uruguay', Decimal('8.7')),
#  ('Jamaica', Decimal('8.7')),
#  ('Virgin Islands, British', Decimal('8.9')),
#  ('Panama', Decimal('9.0')),
#  ('Libyan Arab Jamahiriya', Decimal('9.0')),
#  ('Northern Mariana Islands', Decimal('9.0')),
#  ('Puerto Rico', Decimal('9.1')),
#  ('Chile', Decimal('9.2')),
#  ('Portugal', Decimal('9.3')),
#  ('Costa Rica', Decimal('9.3')),
#  ('Anguilla', Decimal('9.6')),
#  ('French Guiana', Decimal('9.6')),
#  ('Kuwait', Decimal('9.6')),
#  ('Cuba', Decimal('9.7')),
#  ('Taiwan', Decimal('9.9')),
#  ('Denmark', Decimal('10.0')),
#  ('Cyprus', Decimal('10.2')),
#  ('Ireland', Decimal('10.3')),
#  ('Saint Helena', Decimal('10.3')),
#  ('Bermuda', Decimal('10.4')),
#  ('Guadeloupe', Decimal('10.5')),
#  ('United States', Decimal('10.6')),
#  ('Luxembourg', Decimal('10.6')),
#  ('Germany', Decimal('10.9')),
#  ('Finland', Decimal('10.9')),
#  ('Jordan', Decimal('10.9')),
#  ('Saint Pierre and Miquelon', Decimal('11.1')),
#  ('Austria', Decimal('11.2')),
#  ('United Kingdom', Decimal('11.2')),
#  ('New Zealand', Decimal('11.3')),
#  ('Guam', Decimal('11.3')),
#  ('Belgium', Decimal('11.3')),
#  ('Malta', Decimal('11.4')),
#  ('Montserrat', Decimal('11.5')),
#  ('Virgin Islands, U.S.', Decimal('11.6')),
#  ('Martinique', Decimal('11.8')),
#  ('Netherlands', Decimal('11.8')),
#  ('Greece', Decimal('11.9')),
#  ('Faroe Islands', Decimal('11.9')),
#  ('Aruba', Decimal('11.9')),
#  ('Israel', Decimal('12.1')),
#  ('Norway', Decimal('12.2')),
#  ('Spain', Decimal('12.3')),
#  ('Monaco', Decimal('12.3')),
#  ('France', Decimal('12.3')),
#  ('Liechtenstein', Decimal('12.3')),
#  ('Cayman Islands', Decimal('12.4')),
#  ('Gibraltar', Decimal('12.5')),
#  ('Italy', Decimal('12.5')),
#  ('Canada', Decimal('12.9')),
#  ('Iceland', Decimal('12.9')),
#  ('Hong Kong', Decimal('13.0')),
#  ('Switzerland', Decimal('13.1')),
#  ('Sweden', Decimal('13.1')),
#  ('Australia', Decimal('13.3')),
#  ('Singapore', Decimal('13.6')),
#  ('Japan', Decimal('14.2')),
#  ('San Marino', Decimal('14.6')),
#  ('Macao', Decimal('15.1')),
#  ('Andorra', Decimal('17.0'))]

# %% [markdown]
# ### 3.2
#
# rubric={accuracy:2}

# %% [markdown]
# Write a query that returns country, continent and city names, as well as the ratio of the population of each city to the population of the country where it's located, expressed as a percentage value. Furthermore, your query should also return the population rank of each city among all other cities in the same continent in descending order.
#
# Your results should look like this:
#
# <img src="img/3_2.png" width="700">
#
# Use the above image to name and format your columns properly.
#
# > **Note:** The order of your returned rows might be different from mine, but that is fine.

# %%
# %%sql
#
# SELECT
#     c.name AS country,
#     c.continent,
#     ci.name AS city,
#     ROUND((ci.population::NUMERIC / c.population) * 100, 2) || '%' AS city_pop_ratio,
#     RANK() OVER (PARTITION BY c.continent ORDER BY ci.population DESC) AS rank_in_continent
# FROM
#     country c
# JOIN
#     city ci
# ON
#     c.code = ci.countrycode
# WHERE
#     c.population IS NOT NULL AND ci.population IS NOT NULL
# ORDER BY
#     c.continent, rank_in_continent ASC;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 4079 rows affected.
# [('Egypt', 'Africa', 'Cairo', '9.92%', 1),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kinshasa', '9.80%', 2),
#  ('Egypt', 'Africa', 'Alexandria', '4.86%', 3),
#  ('Morocco', 'Africa', 'Casablanca', '10.37%', 4),
#  ('Côte d\x92Ivoire', 'Africa', 'Abidjan', '16.91%', 5),
#  ('Ethiopia', 'Africa', 'Addis Abeba', '3.99%', 6),
#  ('South Africa', 'Africa', 'Cape Town', '5.83%', 7),
#  ('Kenya', 'Africa', 'Nairobi', '7.61%', 8),
#  ('Egypt', 'Africa', 'Giza', '3.25%', 9),
#  ('Algeria', 'Africa', 'Alger', '6.89%', 10),
#  ('Angola', 'Africa', 'Luanda', '15.70%', 11),
#  ('Tanzania', 'Africa', 'Dar es Salaam', '5.21%', 12),
#  ('Libyan Arab Jamahiriya', 'Africa', 'Tripoli', '30.01%', 13),
#  ('Nigeria', 'Africa', 'Lagos', '1.36%', 14),
#  ('Cameroon', 'Africa', 'Douala', '9.60%', 15),
#  ('Nigeria', 'Africa', 'Ibadan', '1.28%', 16),
#  ('Zimbabwe', 'Africa', 'Harare', '12.08%', 17),
#  ('Cameroon', 'Africa', 'Yaoundé', '9.10%', 18),
#  ('Zambia', 'Africa', 'Lusaka', '14.36%', 19),
#  ('Sudan', 'Africa', 'Omdurman', '4.31%', 20),
#  ('Guinea', 'Africa', 'Conakry', '14.68%', 21),
#  ('Ghana', 'Africa', 'Accra', '5.29%', 22),
#  ('Mozambique', 'Africa', 'Maputo', '5.18%', 23),
#  ('Somalia', 'Africa', 'Mogadishu', '9.87%', 24),
#  ('Congo', 'Africa', 'Brazzaville', '32.28%', 25),
#  ('Sudan', 'Africa', 'Khartum', '3.21%', 26),
#  ('South Africa', 'Africa', 'Soweto', '2.24%', 27),
#  ('Uganda', 'Africa', 'Kampala', '4.09%', 28),
#  ('Egypt', 'Africa', 'Shubra al-Khayma', '1.27%', 29),
#  ('Senegal', 'Africa', 'Pikine', '9.02%', 30),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Lubumbashi', '1.65%', 31),
#  ('Liberia', 'Africa', 'Monrovia', '26.95%', 32),
#  ('Sierra Leone', 'Africa', 'Freetown', '17.51%', 32),
#  ('Burkina Faso', 'Africa', 'Ouagadougou', '6.90%', 34),
#  ('Mali', 'Africa', 'Bamako', '7.21%', 35),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Mbuji-Mayi', '1.56%', 36),
#  ('Libyan Arab Jamahiriya', 'Africa', 'Bengasi', '14.34%', 37),
#  ('Senegal', 'Africa', 'Dakar', '8.28%', 38),
#  ('South Africa', 'Africa', 'Johannesburg', '1.87%', 39),
#  ('South Africa', 'Africa', 'Port Elizabeth', '1.86%', 40),
#  ('Nigeria', 'Africa', 'Ogbomosho', '0.65%', 41),
#  ('Sudan', 'Africa', 'Sharq al-Nil', '2.38%', 42),
#  ('Tunisia', 'Africa', 'Tunis', '7.20%', 43),
#  ('Madagascar', 'Africa', 'Antananarivo', '4.24%', 44),
#  ('Nigeria', 'Africa', 'Kano', '0.60%', 45),
#  ('Mauritania', 'Africa', 'Nouakchott', '24.99%', 46),
#  ('South Africa', 'Africa', 'Pretoria', '1.63%', 47),
#  ('South Africa', 'Africa', 'Inanda', '1.57%', 48),
#  ('Morocco', 'Africa', 'Rabat', '2.20%', 49),
#  ('Morocco', 'Africa', 'Marrakech', '2.19%', 50),
#  ('Zimbabwe', 'Africa', 'Bulawayo', '5.33%', 51),
#  ('Algeria', 'Africa', 'Oran', '1.94%', 52),
#  ('South Africa', 'Africa', 'Durban', '1.40%', 53),
#  ('Morocco', 'Africa', 'Fès', '1.91%', 54),
#  ('Benin', 'Africa', 'Cotonou', '8.80%', 55),
#  ('Chad', 'Africa', 'N´Djaména', '6.94%', 56),
#  ('Central African Republic', 'Africa', 'Bangui', '14.50%', 57),
#  ('Morocco', 'Africa', 'Tanger', '1.84%', 58),
#  ('Morocco', 'Africa', 'Salé', '1.78%', 59),
#  ('Congo', 'Africa', 'Pointe-Noire', '16.99%', 60),
#  ('Malawi', 'Africa', 'Blantyre', '4.38%', 61),
#  ('Nigeria', 'Africa', 'Oshogbo', '0.43%', 62),
#  ('Nigeria', 'Africa', 'Ilorin', '0.43%', 63),
#  ('Egypt', 'Africa', 'Port Said', '0.69%', 64),
#  ('South Africa', 'Africa', 'Vanderbijlpark', '1.16%', 65),
#  ('Kenya', 'Africa', 'Mombasa', '1.54%', 66),
#  ('Morocco', 'Africa', 'Meknès', '1.62%', 67),
#  ('Algeria', 'Africa', 'Constantine', '1.41%', 68),
#  ('South Africa', 'Africa', 'Kempton Park', '1.10%', 69),
#  ('Malawi', 'Africa', 'Lilongwe', '3.99%', 70),
#  ('Eritrea', 'Africa', 'Asmara', '11.19%', 71),
#  ('Nigeria', 'Africa', 'Abeokuta', '0.38%', 72),
#  ('Mozambique', 'Africa', 'Matola', '2.16%', 73),
#  ('Niger', 'Africa', 'Niamey', '3.91%', 74),
#  ('Gabon', 'Africa', 'Libreville', '34.18%', 75),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kolwezi', '0.81%', 76),
#  ('Egypt', 'Africa', 'Suez', '0.61%', 77),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kisangani', '0.81%', 78),
#  ('South Africa', 'Africa', 'Alberton', '1.02%', 79),
#  ('Nigeria', 'Africa', 'Port Harcourt', '0.37%', 80),
#  ('Mozambique', 'Africa', 'Beira', '2.02%', 81),
#  ('Egypt', 'Africa', 'al-Mahallat al-Kubra', '0.58%', 82),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kananga', '0.76%', 83),
#  ('Ghana', 'Africa', 'Kumasi', '1.91%', 84),
#  ('Djibouti', 'Africa', 'Djibouti', '60.03%', 85),
#  ('Nigeria', 'Africa', 'Zaria', '0.34%', 86),
#  ('South Africa', 'Africa', 'Pinetown', '0.94%', 87),
#  ('Nigeria', 'Africa', 'Ilesha', '0.34%', 88),
#  ('Togo', 'Africa', 'Lomé', '8.10%', 89),
#  ('Nigeria', 'Africa', 'Onitsha', '0.33%', 90),
#  ('Egypt', 'Africa', 'Tanta', '0.54%', 91),
#  ('South Africa', 'Africa', 'Pietermaritzburg', '0.92%', 92),
#  ('Egypt', 'Africa', 'al-Mansura', '0.54%', 93),
#  ('South Africa', 'Africa', 'Benoni', '0.91%', 94),
#  ('Morocco', 'Africa', 'Oujda', '1.29%', 95),
#  ('Nigeria', 'Africa', 'Iwo', '0.32%', 96),
#  ('Egypt', 'Africa', 'Luxor', '0.53%', 97),
#  ('Nigeria', 'Africa', 'Ado-Ekiti', '0.32%', 98),
#  ('Nigeria', 'Africa', 'Abuja', '0.31%', 99),
#  ('Egypt', 'Africa', 'Asyut', '0.50%', 100),
#  ('Nigeria', 'Africa', 'Kaduna', '0.31%', 101),
#  ('South Africa', 'Africa', 'Randburg', '0.85%', 102),
#  ('South Africa', 'Africa', 'Umlazi', '0.84%', 103),
#  ('South Africa', 'Africa', 'Bloemfontein', '0.83%', 104),
#  ('Nigeria', 'Africa', 'Mushin', '0.30%', 105),
#  ('Côte d\x92Ivoire', 'Africa', 'Bouaké', '2.23%', 106),
#  ('Zambia', 'Africa', 'Ndola', '3.59%', 107),
#  ('South Africa', 'Africa', 'Vereeniging', '0.81%', 108),
#  ('Nigeria', 'Africa', 'Maiduguri', '0.29%', 109),
#  ('Nigeria', 'Africa', 'Enugu', '0.28%', 110),
#  ('Sudan', 'Africa', 'Port Sudan', '1.05%', 111),
#  ('Nigeria', 'Africa', 'Ede', '0.28%', 112),
#  ('Mozambique', 'Africa', 'Nampula', '1.54%', 113),
#  ('Burundi', 'Africa', 'Bujumbura', '4.48%', 114),
#  ('Burkina Faso', 'Africa', 'Bobo-Dioulasso', '2.51%', 114),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Likasi', '0.58%', 116),
#  ('Nigeria', 'Africa', 'Aba', '0.27%', 117),
#  ('Lesotho', 'Africa', 'Maseru', '13.79%', 118),
#  ('Nigeria', 'Africa', 'Ife', '0.27%', 119),
#  ('Morocco', 'Africa', 'Kénitra', '1.03%', 120),
#  ('Zambia', 'Africa', 'Kitwe', '3.15%', 121),
#  ('Rwanda', 'Africa', 'Kigali', '3.70%', 122),
#  ('South Africa', 'Africa', 'Wonderboom', '0.70%', 123),
#  ('South Africa', 'Africa', 'Roodepoort', '0.69%', 124),
#  ('Morocco', 'Africa', 'Tétouan', '0.98%', 125),
#  ('Egypt', 'Africa', 'Bahtim', '0.40%', 126),
#  ('Zimbabwe', 'Africa', 'Chitungwiza', '2.36%', 127),
#  ('Egypt', 'Africa', 'Zagazig', '0.39%', 128),
#  ('Nigeria', 'Africa', 'Ila', '0.24%', 129),
#  ('South Africa', 'Africa', 'Boksburg', '0.65%', 130),
#  ('Morocco', 'Africa', 'Safi', '0.93%', 131),
#  ('South Africa', 'Africa', 'Klerksdorp', '0.65%', 132),
#  ('Egypt', 'Africa', 'al-Faiyum', '0.38%', 133),
#  ('Tunisia', 'Africa', 'Sfax', '2.69%', 134),
#  ('Nigeria', 'Africa', 'Oyo', '0.23%', 135),
#  ('Egypt', 'Africa', 'Ismailia', '0.37%', 136),
#  ('Senegal', 'Africa', 'Thiès', '2.62%', 137),
#  ('Nigeria', 'Africa', 'Ikerre', '0.22%', 138),
#  ('South Africa', 'Africa', 'Soshanguve', '0.60%', 139),
#  ('Guinea-Bissau', 'Africa', 'Bissau', '19.87%', 140),
#  ('Sudan', 'Africa', 'Kassala', '0.80%', 141),
#  ('Egypt', 'Africa', 'Kafr al-Dawwar', '0.34%', 142),
#  ('Sudan', 'Africa', 'Obeid', '0.78%', 143),
#  ('Nigeria', 'Africa', 'Benin City', '0.21%', 144),
#  ('Sudan', 'Africa', 'Nyala', '0.77%', 145),
#  ('South Africa', 'Africa', 'Newcastle', '0.55%', 146),
#  ('Algeria', 'Africa', 'Annaba', '0.71%', 147),
#  ('South Africa', 'Africa', 'East London', '0.55%', 148),
#  ('Egypt', 'Africa', 'Assuan', '0.32%', 149),
#  ('Nigeria', 'Africa', 'Iseyin', '0.19%', 150),
#  ('Botswana', 'Africa', 'Gaborone', '13.13%', 151),
#  ('Egypt', 'Africa', 'Damanhur', '0.31%', 152),
#  ('Sudan', 'Africa', 'Wad Madani', '0.72%', 153),
#  ('Nigeria', 'Africa', 'Katsina', '0.19%', 154),
#  ('Nigeria', 'Africa', 'Jos', '0.19%', 155),
#  ('Nigeria', 'Africa', 'Sokoto', '0.18%', 156),
#  ('South Africa', 'Africa', 'Welkom', '0.50%', 157),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Bukavu', '0.39%', 158),
#  ('Egypt', 'Africa', 'al-Minya', '0.29%', 159),
#  ('Senegal', 'Africa', 'Kaolack', '2.10%', 160),
#  ('Nigeria', 'Africa', 'Ilobu', '0.18%', 160),
#  ('South Africa', 'Africa', 'Kimberley', '0.49%', 162),
#  ('Nigeria', 'Africa', 'Offa', '0.18%', 163),
#  ('Tunisia', 'Africa', 'Ariana', '2.06%', 164),
#  ('Benin', 'Africa', 'Porto-Novo', '3.18%', 165),
#  ('Kenya', 'Africa', 'Kisumu', '0.64%', 166),
#  ('South Africa', 'Africa', 'Uitenhage', '0.48%', 167),
#  ('Senegal', 'Africa', 'Ziguinchor', '2.03%', 168),
#  ('Sudan', 'Africa', 'al-Qadarif', '0.65%', 169),
#  ('South Africa', 'Africa', 'Chatsworth', '0.47%', 170),
#  ('Tanzania', 'Africa', 'Dodoma', '0.56%', 171),
#  ('Nigeria', 'Africa', 'Ikorodu', '0.17%', 172),
#  ('Nigeria', 'Africa', 'Ilawe-Ekiti', '0.17%', 173),
#  ('Nigeria', 'Africa', 'Owo', '0.16%', 174),
#  ('Algeria', 'Africa', 'Batna', '0.58%', 175),
#  ('South Africa', 'Africa', 'Mdantsane', '0.45%', 176),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kikwit', '0.35%', 177),
#  ('South Africa', 'Africa', 'Krugersdorp', '0.45%', 178),
#  ('Nigeria', 'Africa', 'Ikirun', '0.16%', 179),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Tshikapa', '0.35%', 180),
#  ('Algeria', 'Africa', 'Sétif', '0.57%', 181),
#  ('Tunisia', 'Africa', 'Ettadhamen', '1.86%', 182),
#  ('South Africa', 'Africa', 'Botshabelo', '0.44%', 183),
#  ('Cameroon', 'Africa', 'Garoua', '1.17%', 184),
#  ('Nigeria', 'Africa', 'Shaki', '0.16%', 185),
#  ('Nigeria', 'Africa', 'Calabar', '0.16%', 186),
#  ('Nigeria', 'Africa', 'Ondo', '0.16%', 187),
#  ('Sudan', 'Africa', 'Kusti', '0.59%', 188),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Matadi', '0.33%', 189),
#  ('Tanzania', 'Africa', 'Mwanza', '0.51%', 190),
#  ('Egypt', 'Africa', 'Bani Suwayf', '0.25%', 191),
#  ('South Africa', 'Africa', 'Brakpan', '0.42%', 192),
#  ('Egypt', 'Africa', 'Qina', '0.25%', 193),
#  ('Mozambique', 'Africa', 'Chimoio', '0.87%', 194),
#  ('Egypt', 'Africa', 'Sawhaj', '0.25%', 195),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Mbandaka', '0.33%', 196),
#  ('Namibia', 'Africa', 'Windhoek', '9.79%', 197),
#  ('Western Sahara', 'Africa', 'El-Aaiún', '57.68%', 197),
#  ('South Africa', 'Africa', 'Witbank', '0.41%', 199),
#  ('Ethiopia', 'Africa', 'Dire Dawa', '0.26%', 200),
#  ('South Africa', 'Africa', 'Oberholzer', '0.41%', 201),
#  ('Zimbabwe', 'Africa', 'Mount Darwin', '1.41%', 202),
#  ('South Africa', 'Africa', 'Germiston', '0.41%', 203),
#  ('Kenya', 'Africa', 'Nakuru', '0.54%', 204),
#  ('Angola', 'Africa', 'Huambo', '1.27%', 205),
#  ('Nigeria', 'Africa', 'Akure', '0.15%', 206),
#  ('South Africa', 'Africa', 'Springs', '0.40%', 207),
#  ('Egypt', 'Africa', 'Shibin al-Kawm', '0.23%', 208),
#  ('South Africa', 'Africa', 'Westonaria', '0.40%', 209),
#  ('Mozambique', 'Africa', 'Naçala-Porto', '0.80%', 210),
#  ('Nigeria', 'Africa', 'Gusau', '0.14%', 211),
#  ('Tanzania', 'Africa', 'Zanzibar', '0.47%', 212),
#  ('Nigeria', 'Africa', 'Ijebu-Ode', '0.14%', 213),
#  ('Morocco', 'Africa', 'Agadir', '0.55%', 214),
#  ('Morocco', 'Africa', 'Mohammedia', '0.55%', 215),
#  ('Zambia', 'Africa', 'Kabwe', '1.68%', 216),
#  ('Algeria', 'Africa', 'Sidi Bel Abbès', '0.49%', 217),
#  ('Nigeria', 'Africa', 'Effon-Alaiye', '0.14%', 218),
#  ('Morocco', 'Africa', 'Khouribga', '0.54%', 219),
#  ('Ghana', 'Africa', 'Tamale', '0.75%', 220),
#  ('Mozambique', 'Africa', 'Quelimane', '0.76%', 221),
#  ('Senegal', 'Africa', 'Rufisque', '1.58%', 222),
#  ('Egypt', 'Africa', 'Bulaq al-Dakrur', '0.22%', 223),
#  ('Nigeria', 'Africa', 'Kumo', '0.13%', 224),
#  ('Nigeria', 'Africa', 'Shomolu', '0.13%', 225),
#  ('Tunisia', 'Africa', 'Sousse', '1.52%', 226),
#  ('Egypt', 'Africa', 'Banha', '0.21%', 227),
#  ('Cameroon', 'Africa', 'Maroua', '0.95%', 228),
#  ('Nigeria', 'Africa', 'Oka-Akoko', '0.13%', 229),
#  ('Zambia', 'Africa', 'Chingola', '1.55%', 230),
#  ('Sudan', 'Africa', 'al-Fashir', '0.48%', 231),
#  ('Nigeria', 'Africa', 'Ikare', '0.13%', 232),
#  ('Morocco', 'Africa', 'Beni-Mellal', '0.49%', 233),
#  ('Nigeria', 'Africa', 'Sapele', '0.12%', 234),
#  ('Nigeria', 'Africa', 'Deba Habe', '0.12%', 235),
#  ('Mauritius', 'Africa', 'Port-Louis', '11.93%', 236),
#  ('Cameroon', 'Africa', 'Bamenda', '0.91%', 237),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Mwene-Ditu', '0.27%', 238),
#  ('Tanzania', 'Africa', 'Tanga', '0.41%', 239),
#  ('Nigeria', 'Africa', 'Minna', '0.12%', 240),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Boma', '0.26%', 241),
#  ('Benin', 'Africa', 'Djougou', '2.20%', 242),
#  ('Senegal', 'Africa', 'Saint-Louis', '1.40%', 243),
#  ('Réunion', 'Africa', 'Saint-Denis', '18.81%', 244),
#  ('Zimbabwe', 'Africa', 'Mutare', '1.13%', 245),
#  ('Cameroon', 'Africa', 'Bafoussam', '0.87%', 246),
#  ('Tanzania', 'Africa', 'Mbeya', '0.39%', 247),
#  ('Angola', 'Africa', 'Lobito', '1.01%', 248),
#  ('Côte d\x92Ivoire', 'Africa', 'Yamoussoukro', '0.88%', 248),
#  ('Algeria', 'Africa', 'Skikda', '0.41%', 250),
#  ('Angola', 'Africa', 'Benguela', '1.00%', 251),
#  ('Algeria', 'Africa', 'Biskra', '0.41%', 252),
#  ('Zimbabwe', 'Africa', 'Gweru', '1.10%', 253),
#  ('Ethiopia', 'Africa', 'Nazret', '0.20%', 254),
#  ('Madagascar', 'Africa', 'Toamasina', '0.80%', 255),
#  ('Algeria', 'Africa', 'Blida (el-Boulaida)', '0.40%', 256),
#  ('Egypt', 'Africa', 'Warraq al-Arab', '0.19%', 257),
#  ('Morocco', 'Africa', 'Témara', '0.45%', 258),
#  ('Nigeria', 'Africa', 'Warri', '0.11%', 259),
#  ('Nigeria', 'Africa', 'Bida', '0.11%', 260),
#  ('Egypt', 'Africa', 'Kafr al-Shaykh', '0.18%', 261),
#  ('Mozambique', 'Africa', 'Mocuba', '0.63%', 262),
#  ('Zambia', 'Africa', 'Mufulira', '1.35%', 263),
#  ('Nigeria', 'Africa', 'Ikire', '0.11%', 264),
#  ('Nigeria', 'Africa', 'Makurdi', '0.11%', 265),
#  ('Nigeria', 'Africa', 'Lafia', '0.11%', 266),
#  ('Côte d\x92Ivoire', 'Africa', 'Daloa', '0.82%', 267),
#  ('Libyan Arab Jamahiriya', 'Africa', 'Misrata', '2.17%', 268),
#  ('Niger', 'Africa', 'Zinder', '1.13%', 269),
#  ('South Africa', 'Africa', 'Randfontein', '0.30%', 270),
#  ('Madagascar', 'Africa', 'Antsirabé', '0.75%', 271),
#  ('Nigeria', 'Africa', 'Inisa', '0.11%', 272),
#  ('Egypt', 'Africa', 'Mallawi', '0.17%', 273),
#  ('Morocco', 'Africa', 'El Jadida', '0.42%', 274),
#  ('Angola', 'Africa', 'Namibe', '0.92%', 275),
#  ('Zambia', 'Africa', 'Luanshya', '1.29%', 276),
#  ('Tanzania', 'Africa', 'Morogoro', '0.35%', 277),
#  ('Nigeria', 'Africa', 'Shagamu', '0.11%', 278),
#  ('Algeria', 'Africa', 'Béjaïa', '0.37%', 279),
#  ('Kenya', 'Africa', 'Machakos', '0.39%', 280),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Uvira', '0.22%', 281),
#  ('Algeria', 'Africa', 'Mostaganem', '0.37%', 282),
#  ('Sudan', 'Africa', 'Juba', '0.39%', 283),
#  ('Egypt', 'Africa', 'Bilbays', '0.17%', 284),
#  ('Tunisia', 'Africa', 'Kairouan', '1.18%', 285),
#  ('Niger', 'Africa', 'Maradi', '1.05%', 286),
#  ('Cameroon', 'Africa', 'Nkongsamba', '0.75%', 287),
#  ('Morocco', 'Africa', 'Nador', '0.40%', 288),
#  ('Ethiopia', 'Africa', 'Gonder', '0.18%', 289),
#  ('Algeria', 'Africa', 'Tébessa', '0.36%', 290),
#  ('Kenya', 'Africa', 'Eldoret', '0.37%', 291),
#  ('Nigeria', 'Africa', 'Awka', '0.10%', 292),
#  ('Algeria', 'Africa', 'Tlemcen (Tilimsen)', '0.35%', 293),
#  ('Ghana', 'Africa', 'Tema', '0.54%', 294),
#  ('Côte d\x92Ivoire', 'Africa', 'Korhogo', '0.74%', 295),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Butembo', '0.21%', 296),
#  ('Senegal', 'Africa', 'Mbour', '1.15%', 297),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Goma', '0.21%', 298),
#  ('Tunisia', 'Africa', 'Biserta', '1.14%', 299),
#  ('Nigeria', 'Africa', 'Gombe', '0.10%', 300),
#  ('Algeria', 'Africa', 'Béchar', '0.34%', 301),
#  ('Morocco', 'Africa', 'Ksar el Kebir', '0.38%', 302),
#  ('Nigeria', 'Africa', 'Igboho', '0.10%', 303),
#  ('Tunisia', 'Africa', 'Gabès', '1.11%', 304),
#  ('Nigeria', 'Africa', 'Ejigbo', '0.09%', 305),
#  ('South Africa', 'Africa', 'Paarl', '0.26%', 306),
#  ('Nigeria', 'Africa', 'Agege', '0.09%', 307),
#  ('Burkina Faso', 'Africa', 'Koudougou', '0.88%', 307),
#  ('Ghana', 'Africa', 'Sekondi-Takoradi', '0.51%', 309),
#  ('Benin', 'Africa', 'Parakou', '1.70%', 310),
#  ('Nigeria', 'Africa', 'Ise-Ekiti', '0.09%', 311),
#  ('Nigeria', 'Africa', 'Ugep', '0.09%', 312),
#  ('Gambia', 'Africa', 'Serekunda', '7.86%', 312),
#  ('Tanzania', 'Africa', 'Arusha', '0.31%', 314),
#  ('Mozambique', 'Africa', 'Tete', '0.52%', 315),
#  ('South Africa', 'Africa', 'Potchefstroom', '0.25%', 316),
#  ('Botswana', 'Africa', 'Francistown', '6.28%', 317),
#  ('Egypt', 'Africa', 'Mit Ghamr', '0.15%', 318),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Kalemie', '0.20%', 319),
#  ('Nigeria', 'Africa', 'Epe', '0.09%', 320),
#  ('Madagascar', 'Africa', 'Mahajanga', '0.63%', 321),
#  ('Mauritius', 'Africa', 'Beau Bassin-Rose Hill', '8.69%', 322),
#  ('Egypt', 'Africa', 'al-Arish', '0.15%', 323),
#  ('Algeria', 'Africa', 'Tiaret', '0.32%', 324),
#  ('Chad', 'Africa', 'Moundou', '1.30%', 325),
#  ('Mozambique', 'Africa', 'Xai-Xai', '0.51%', 326),
#  ('Senegal', 'Africa', 'Diourbel', '1.05%', 327),
#  ('Mozambique', 'Africa', 'Gurue', '0.50%', 328),
#  ('Madagascar', 'Africa', 'Fianarantsoa', '0.62%', 329),
#  ('Mauritius', 'Africa', 'Vacoas-Phoenix', '8.50%', 330),
#  ('Egypt', 'Africa', 'Talkha', '0.14%', 331),
#  ('Mauritania', 'Africa', 'Nouâdhibou', '3.66%', 332),
#  ('Ethiopia', 'Africa', 'Dese', '0.16%', 333),
#  ('Egypt', 'Africa', 'Qalyub', '0.14%', 334),
#  ('South Africa', 'Africa', 'Rustenburg', '0.24%', 335),
#  ('Ethiopia', 'Africa', 'Mekele', '0.15%', 336),
#  ('Tanzania', 'Africa', 'Moshi', '0.29%', 337),
#  ('Algeria', 'Africa', 'Ech-Chleff (el-Asnam)', '0.31%', 338),
#  ('South Africa', 'Africa', 'Nigel', '0.24%', 339),
#  ('Morocco', 'Africa', 'Settat', '0.34%', 340),
#  ('Ethiopia', 'Africa', 'Bahir Dar', '0.15%', 341),
#  ('Egypt', 'Africa', 'Jirja', '0.14%', 342),
#  ('Kenya', 'Africa', 'Meru', '0.32%', 343),
#  ('Cape Verde', 'Africa', 'Praia', '22.15%', 344),
#  ('Egypt', 'Africa', 'Idfu', '0.14%', 345),
#  ('Mozambique', 'Africa', 'Maxixe', '0.48%', 346),
#  ('South Africa', 'Africa', 'George', '0.23%', 347),
#  ('Tanzania', 'Africa', 'Tabora', '0.28%', 348),
#  ('Morocco', 'Africa', 'Taza', '0.33%', 349),
#  ('Egypt', 'Africa', 'al-Hawamidiya', '0.13%', 350),
#  ('Egypt', 'Africa', 'Disuq', '0.13%', 351),
#  ('Kenya', 'Africa', 'Nyeri', '0.30%', 352),
#  ('Morocco', 'Africa', 'El Araich', '0.32%', 353),
#  ('Somalia', 'Africa', 'Hargeysa', '0.89%', 354),
#  ('Somalia', 'Africa', 'Kismaayo', '0.89%', 354),
#  ('Algeria', 'Africa', 'Ghardaïa', '0.28%', 356),
#  ('Libyan Arab Jamahiriya', 'Africa', 'al-Zawiya', '1.59%', 357),
#  ('South Africa', 'Africa', 'Ladysmith', '0.22%', 358),
#  ('Swaziland', 'Africa', 'Mbabane', '6.05%', 359),
#  ('Sao Tome and Principe', 'Africa', 'São Tomé', '33.70%', 360),
#  ('Gambia', 'Africa', 'Banjul', '3.24%', 361),
#  ('Seychelles', 'Africa', 'Victoria', '53.25%', 362),
#  ('Equatorial Guinea', 'Africa', 'Malabo', '8.83%', 363),
#  ('Comoros', 'Africa', 'Moroni', '6.23%', 364),
#  ('Mayotte', 'Africa', 'Mamoutzou', '8.05%', 365),
#  ('Saint Helena', 'Africa', 'Jamestown', '25.00%', 366),
#  ('India', 'Asia', 'Mumbai (Bombay)', '1.04%', 1),
#  ('South Korea', 'Asia', 'Seoul', '21.31%', 2),
#  ('China', 'Asia', 'Shanghai', '0.76%', 3),
#  ('Indonesia', 'Asia', 'Jakarta', '4.53%', 4),
#  ('Pakistan', 'Asia', 'Karachi', '5.92%', 5),
#  ('Turkey', 'Asia', 'Istanbul', '13.20%', 6),
#  ('Japan', 'Asia', 'Tokyo', '6.30%', 7),
#  ('China', 'Asia', 'Peking', '0.58%', 8),
#  ('India', 'Asia', 'Delhi', '0.71%', 9),
#  ('Iran', 'Asia', 'Teheran', '9.98%', 10),
#  ('China', 'Asia', 'Chongqing', '0.50%', 11),
#  ('Thailand', 'Asia', 'Bangkok', '10.29%', 12),
#  ('China', 'Asia', 'Tianjin', '0.41%', 13),
#  ('Pakistan', 'Asia', 'Lahore', '3.24%', 14),
#  ('India', 'Asia', 'Calcutta [Kolkata]', '0.43%', 15),
#  ('China', 'Asia', 'Wuhan', '0.34%', 16),
#  ('Iraq', 'Asia', 'Baghdad', '18.76%', 17),
#  ('China', 'Asia', 'Harbin', '0.34%', 18),
#  ('China', 'Asia', 'Shenyang', '0.33%', 19),
#  ('China', 'Asia', 'Kanton [Guangzhou]', '0.33%', 20),
#  ('Singapore', 'Asia', 'Singapore', '112.64%', 21),
#  ('Vietnam', 'Asia', 'Ho Chi Minh City', '4.99%', 22),
#  ('India', 'Asia', 'Chennai (Madras)', '0.38%', 23),
#  ('South Korea', 'Asia', 'Pusan', '8.12%', 24),
#  ('Bangladesh', 'Asia', 'Dhaka', '2.80%', 25),
#  ('Myanmar', 'Asia', 'Rangoon (Yangon)', '7.37%', 26),
#  ('China', 'Asia', 'Chengdu', '0.26%', 27),
#  ('Japan', 'Asia', 'Jokohama [Yokohama]', '2.64%', 28),
#  ('Saudi Arabia', 'Asia', 'Riyadh', '15.38%', 29),
#  ('Turkey', 'Asia', 'Ankara', '4.56%', 30),
#  ('India', 'Asia', 'Hyderabad', '0.29%', 31),
#  ('India', 'Asia', 'Ahmedabad', '0.28%', 32),
#  ('China', 'Asia', 'Nanking [Nanjing]', '0.22%', 33),
#  ('China', 'Asia', 'Changchun', '0.22%', 34),
#  ('China', 'Asia', 'Xi´an', '0.22%', 35),
#  ('China', 'Asia', 'Dalian', '0.21%', 36),
#  ('Indonesia', 'Asia', 'Surabaya', '1.26%', 37),
#  ('India', 'Asia', 'Bangalore', '0.26%', 38),
#  ('Taiwan', 'Asia', 'Taipei', '11.87%', 39),
#  ('China', 'Asia', 'Qingdao', '0.20%', 40),
#  ('Japan', 'Asia', 'Osaka', '2.05%', 41),
#  ('South Korea', 'Asia', 'Inchon', '5.46%', 42),
#  ('South Korea', 'Asia', 'Taegu', '5.44%', 43),
#  ('North Korea', 'Asia', 'Pyongyang', '10.33%', 44),
#  ('Indonesia', 'Asia', 'Bandung', '1.15%', 45),
#  ('China', 'Asia', 'Jinan', '0.18%', 46),
#  ('China', 'Asia', 'Hangzhou', '0.17%', 47),
#  ('Philippines', 'Asia', 'Quezon', '2.86%', 48),
#  ('Japan', 'Asia', 'Nagoya', '1.70%', 49),
#  ('Turkey', 'Asia', 'Izmir', '3.20%', 50),
#  ('Uzbekistan', 'Asia', 'Toskent', '8.71%', 51),
#  ('China', 'Asia', 'Zhengzhou', '0.16%', 52),
#  ('Saudi Arabia', 'Asia', 'Jedda', '9.47%', 53),
#  ('China', 'Asia', 'Shijiazhuang', '0.16%', 54),
#  ('Hong Kong', 'Asia', 'Kowloon and New Kowloon', '29.31%', 55),
#  ('Pakistan', 'Asia', 'Faisalabad', '1.26%', 56),
#  ('China', 'Asia', 'Taiyuan', '0.15%', 57),
#  ('Iran', 'Asia', 'Mashhad', '2.79%', 58),
#  ('India', 'Asia', 'Kanpur', '0.18%', 59),
#  ('Indonesia', 'Asia', 'Medan', '0.87%', 60),
#  ('China', 'Asia', 'Kunming', '0.14%', 61),
#  ('China', 'Asia', 'Changsha', '0.14%', 62),
#  ('Japan', 'Asia', 'Sapporo', '1.41%', 63),
#  ('Azerbaijan', 'Asia', 'Baku', '23.12%', 64),
#  ('Afghanistan', 'Asia', 'Kabul', '7.83%', 65),
#  ('China', 'Asia', 'Nanchang', '0.13%', 66),
#  ('India', 'Asia', 'Nagpur', '0.16%', 67),
#  ('India', 'Asia', 'Lucknow', '0.16%', 68),
#  ('China', 'Asia', 'Fuzhou', '0.12%', 69),
#  ('Philippines', 'Asia', 'Manila', '2.08%', 70),
#  ('India', 'Asia', 'Pune', '0.15%', 71),
#  ('China', 'Asia', 'Lanzhou', '0.12%', 72),
#  ('India', 'Asia', 'Surat', '0.15%', 73),
#  ('Taiwan', 'Asia', 'Kaohsiung', '6.63%', 74),
#  ('China', 'Asia', 'Guiyang', '0.11%', 75),
#  ('Japan', 'Asia', 'Kioto', '1.15%', 76),
#  ('India', 'Asia', 'Jaipur', '0.14%', 77),
#  ('South Korea', 'Asia', 'Taejon', '3.04%', 78),
#  ('Japan', 'Asia', 'Kobe', '1.12%', 79),
#  ('Vietnam', 'Asia', 'Hanoi', '1.77%', 80),
#  ('Pakistan', 'Asia', 'Rawalpindi', '0.90%', 81),
#  ('Bangladesh', 'Asia', 'Chittagong', '1.08%', 82),
#  ('China', 'Asia', 'Ningbo', '0.11%', 83),
#  ('China', 'Asia', 'Hefei', '0.11%', 84),
#  ('South Korea', 'Asia', 'Kwangju', '2.92%', 85),
#  ('Syria', 'Asia', 'Damascus', '8.35%', 86),
#  ('Hong Kong', 'Asia', 'Victoria', '19.35%', 87),
#  ('China', 'Asia', 'Urumt\x9ai [Ürümqi]', '0.10%', 88),
#  ('Japan', 'Asia', 'Fukuoka', '1.03%', 89),
#  ('Malaysia', 'Asia', 'Kuala Lumpur', '5.83%', 90),
#  ('Iran', 'Asia', 'Esfahan', '1.87%', 91),
#  ('Syria', 'Asia', 'Aleppo', '7.83%', 92),
#  ('Armenia', 'Asia', 'Yerevan', '35.47%', 93),
#  ('Georgia', 'Asia', 'Tbilisi', '24.86%', 94),
#  ('Indonesia', 'Asia', 'Palembang', '0.58%', 95),
#  ('Japan', 'Asia', 'Kawasaki', '0.96%', 96),
#  ('China', 'Asia', 'Anshan', '0.09%', 97),
#  ('China', 'Asia', 'Fushun', '0.09%', 97),
#  ('Indonesia', 'Asia', 'Tangerang', '0.56%', 99),
#  ('Iran', 'Asia', 'Tabriz', '1.76%', 100),
#  ('Pakistan', 'Asia', 'Multan', '0.76%', 101),
#  ('Philippines', 'Asia', 'Kalookan', '1.55%', 102),
#  ('China', 'Asia', 'Nanning', '0.09%', 103),
#  ('Pakistan', 'Asia', 'Hyderabad', '0.74%', 104),
#  ('Philippines', 'Asia', 'Davao', '1.51%', 105),
#  ('China', 'Asia', 'Zibo', '0.09%', 106),
#  ('Turkey', 'Asia', 'Adana', '1.70%', 107),
#  ('Kazakstan', 'Asia', 'Almaty', '6.96%', 108),
#  ('Pakistan', 'Asia', 'Gujranwala', '0.72%', 109),
#  ('Japan', 'Asia', 'Hiroshima', '0.88%', 110),
#  ('Indonesia', 'Asia', 'Semarang', '0.52%', 111),
#  ('Lebanon', 'Asia', 'Beirut', '33.52%', 112),
#  ('Turkey', 'Asia', 'Bursa', '1.65%', 113),
#  ('India', 'Asia', 'Indore', '0.11%', 114),
#  ('South Korea', 'Asia', 'Ulsan', '2.32%', 115),
#  ('China', 'Asia', 'Qiqihar', '0.08%', 116),
#  ('India', 'Asia', 'Bhopal', '0.10%', 117),
#  ('Indonesia', 'Asia', 'Ujung Pandang', '0.50%', 118),
#  ('Iran', 'Asia', 'Shiraz', '1.56%', 119),
#  ('India', 'Asia', 'Ludhiana', '0.10%', 120),
#  ('China', 'Asia', 'Jilin', '0.08%', 121),
#  ('China', 'Asia', 'Tangshan', '0.08%', 121),
#  ('India', 'Asia', 'Vadodara (Baroda)', '0.10%', 123),
#  ('Japan', 'Asia', 'Kitakyushu', '0.80%', 124),
#  ('India', 'Asia', 'Kalyan', '0.10%', 125),
#  ('Jordan', 'Asia', 'Amman', '19.67%', 126),
#  ('Japan', 'Asia', 'Sendai', '0.78%', 127),
#  ('Pakistan', 'Asia', 'Peshawar', '0.63%', 128),
#  ('China', 'Asia', 'Baotou', '0.08%', 129),
#  ('India', 'Asia', 'Madurai', '0.10%', 130),
#  ('Saudi Arabia', 'Asia', 'Mekka', '4.47%', 131),
#  ('China', 'Asia', 'Shenzhen', '0.07%', 132),
#  ('India', 'Asia', 'Haora (Howrah)', '0.09%', 133),
#  ('Iran', 'Asia', 'Karaj', '1.39%', 134),
#  ('Taiwan', 'Asia', 'Taichung', '4.23%', 135),
#  ('India', 'Asia', 'Varanasi (Benares)', '0.09%', 136),
#  ('India', 'Asia', 'Patna', '0.09%', 137),
#  ('China', 'Asia', 'Hohhot', '0.07%', 138),
#  ('India', 'Asia', 'Srinagar', '0.09%', 139),
#  ('India', 'Asia', 'Agra', '0.09%', 140),
#  ('Myanmar', 'Asia', 'Mandalay', '1.94%', 141),
#  ('Iraq', 'Asia', 'Mosul', '3.80%', 142),
#  ('South Korea', 'Asia', 'Songnam', '1.86%', 143),
#  ('Japan', 'Asia', 'Chiba', '0.68%', 144),
#  ('China', 'Asia', 'Handan', '0.07%', 145),
#  ('China', 'Asia', 'Wuxi', '0.06%', 146),
#  ('India', 'Asia', 'Coimbatore', '0.08%', 147),
#  ('China', 'Asia', 'Xuzhou', '0.06%', 148),
#  ('Iran', 'Asia', 'Ahvaz', '1.19%', 149),
#  ('India', 'Asia', 'Thane (Thana)', '0.08%', 150),
#  ('China', 'Asia', 'Datong', '0.06%', 151),
#  ('China', 'Asia', 'Yichun', '0.06%', 151),
#  ('Japan', 'Asia', 'Sakai', '0.63%', 153),
#  ('India', 'Asia', 'Allahabad', '0.08%', 154),
#  ('Turkey', 'Asia', 'Gaziantep', '1.18%', 155),
#  ('Vietnam', 'Asia', 'Haiphong', '0.98%', 156),
#  ('South Korea', 'Asia', 'Puchon', '1.66%', 157),
#  ('Iran', 'Asia', 'Qom', '1.15%', 158),
#  ('Mongolia', 'Asia', 'Ulan Bator', '29.06%', 159),
#  ('China', 'Asia', 'Benxi', '0.06%', 160),
#  ('China', 'Asia', 'Luoyang', '0.06%', 161),
#  ('South Korea', 'Asia', 'Suwon', '1.61%', 162),
#  ('India', 'Asia', 'Meerut', '0.07%', 163),
#  ('India', 'Asia', 'Vishakhapatnam', '0.07%', 164),
#  ('India', 'Asia', 'Jabalpur', '0.07%', 165),
#  ('Taiwan', 'Asia', 'Tainan', '3.27%', 166),
#  ('Philippines', 'Asia', 'Cebu', '0.95%', 167),
#  ('Indonesia', 'Asia', 'Malang', '0.34%', 168),
#  ('China', 'Asia', 'Suzhou', '0.06%', 169),
#  ('North Korea', 'Asia', 'Hamhung', '2.95%', 170),
#  ('India', 'Asia', 'Amritsar', '0.07%', 171),
#  ('India', 'Asia', 'Faridabad', '0.07%', 172),
#  ('India', 'Asia', 'Vijayawada', '0.07%', 173),
#  ('China', 'Asia', 'Xining', '0.05%', 174),
#  ('China', 'Asia', 'Huainan', '0.05%', 175),
#  ('Iran', 'Asia', 'Kermanshah', '1.02%', 176),
#  ('India', 'Asia', 'Gwalior', '0.07%', 177),
#  ('China', 'Asia', 'Jixi', '0.05%', 178),
#  ('Indonesia', 'Asia', 'Bandar Lampung', '0.32%', 179),
#  ('United Arab Emirates', 'Asia', 'Dubai', '27.41%', 180),
#  ('India', 'Asia', 'Jodhpur', '0.07%', 181),
#  ('Bangladesh', 'Asia', 'Khulna', '0.51%', 182),
#  ('China', 'Asia', 'Daqing', '0.05%', 183),
#  ('India', 'Asia', 'Nashik (Nasik)', '0.06%', 184),
#  ('Japan', 'Asia', 'Kumamoto', '0.52%', 185),
#  ('India', 'Asia', 'Hubli-Dharwad', '0.06%', 186),
#  ('Sri Lanka', 'Asia', 'Colombo', '3.43%', 187),
#  ('Indonesia', 'Asia', 'Bekasi', '0.30%', 188),
#  ('China', 'Asia', 'Fuxin', '0.05%', 189),
#  ('Israel', 'Asia', 'Jerusalem', '10.19%', 190),
#  ('Turkey', 'Asia', 'Konya', '0.94%', 191),
#  ('China', 'Asia', 'Amoy [Xiamen]', '0.05%', 192),
#  ('Japan', 'Asia', 'Okayama', '0.49%', 193),
#  ('China', 'Asia', 'Liuzhou', '0.05%', 194),
#  ('Saudi Arabia', 'Asia', 'Medina', '2.82%', 195),
#  ('India', 'Asia', 'Solapur (Sholapur)', '0.06%', 196),
#  ('Philippines', 'Asia', 'Zamboanga', '0.79%', 197),
#  ('India', 'Asia', 'Ranchi', '0.06%', 198),
#  ('Nepal', 'Asia', 'Kathmandu', '2.47%', 199),
#  ('South Korea', 'Asia', 'Anyang', '1.26%', 200),
#  ('Kyrgyzstan', 'Asia', 'Bishkek', '12.54%', 201),
#  ('Turkey', 'Asia', 'Mersin (Içel)', '0.88%', 202),
#  ('India', 'Asia', 'Bareilly', '0.06%', 203),
#  ('Japan', 'Asia', 'Sagamihara', '0.46%', 204),
#  ('India', 'Asia', 'Guwahati (Gauhati)', '0.06%', 205),
#  ('North Korea', 'Asia', 'Chongjin', '2.42%', 206),
#  ('China', 'Asia', 'Shantou', '0.05%', 207),
#  ('India', 'Asia', 'Shambajinagar (Aurangabad)', '0.06%', 208),
#  ('Cambodia', 'Asia', 'Phnom Penh', '5.11%', 209),
#  ('China', 'Asia', 'Mudanjiang', '0.04%', 210),
#  ('China', 'Asia', 'Jinzhou', '0.04%', 210),
#  ('Japan', 'Asia', 'Hamamatsu', '0.45%', 212),
#  ('North Korea', 'Asia', 'Nampo', '2.36%', 213),
#  ('Turkey', 'Asia', 'Antalya', '0.85%', 214),
#  ('India', 'Asia', 'Cochin (Kochi)', '0.06%', 215),
#  ('South Korea', 'Asia', 'Chonju', '1.20%', 216),
#  ('Pakistan', 'Asia', 'Quetta', '0.36%', 217),
#  ('India', 'Asia', 'Rajkot', '0.06%', 218),
#  ('Japan', 'Asia', 'Kagoshima', '0.43%', 219),
#  ('Japan', 'Asia', 'Funabashi', '0.43%', 220),
#  ('China', 'Asia', 'Yinchuan', '0.04%', 221),
#  ('Turkmenistan', 'Asia', 'Ashgabat', '12.12%', 222),
#  ('India', 'Asia', 'Kota', '0.05%', 223),
#  ('Indonesia', 'Asia', 'Padang', '0.25%', 224),
#  ('Laos', 'Asia', 'Vientiane', '9.79%', 225),
#  ('South Korea', 'Asia', 'Chongju', '1.13%', 226),
#  ('China', 'Asia', 'Changzhou', '0.04%', 227),
#  ('China', 'Asia', 'Zhangjiakou', '0.04%', 227),
#  ('Pakistan', 'Asia', 'Islamabad', '0.34%', 229),
#  ('India', 'Asia', 'Thiruvananthapuram (Trivandrum', '0.05%', 230),
#  ('Tajikistan', 'Asia', 'Dushanbe', '8.47%', 231),
#  ('Taiwan', 'Asia', 'Panchiao', '2.35%', 232),
#  ('China', 'Asia', 'Dandong', '0.04%', 233),
#  ('China', 'Asia', 'Hegang', '0.04%', 233),
#  ('Indonesia', 'Asia', 'Surakarta', '0.24%', 235),
#  ('South Korea', 'Asia', 'Koyang', '1.11%', 236),
#  ('Japan', 'Asia', 'Higashiosaka', '0.41%', 237),
#  ('India', 'Asia', 'Pimpri-Chinchwad', '0.05%', 238),
#  ('Japan', 'Asia', 'Hachioji', '0.41%', 239),
#  ('South Korea', 'Asia', 'Ansan', '1.09%', 240),
#  ('China', 'Asia', 'Kaifeng', '0.04%', 241),
#  ('India', 'Asia', 'Jalandhar (Jullundur)', '0.05%', 242),
#  ('South Korea', 'Asia', 'Pohang', '1.09%', 243),
#  ('Syria', 'Asia', 'Hims', '3.15%', 244),
#  ('India', 'Asia', 'Gorakhpur', '0.05%', 245),
#  ('Philippines', 'Asia', 'Pasig', '0.66%', 246),
#  ('India', 'Asia', 'Chandigarh', '0.05%', 247),
#  ('Yemen', 'Asia', 'Sanaa', '2.78%', 248),
#  ('Japan', 'Asia', 'Niigata', '0.39%', 249),
#  ('China', 'Asia', 'Jiamusi', '0.04%', 250),
#  ('China', 'Asia', 'Liaoyang', '0.04%', 251),
#  ('China', 'Asia', 'Hengyang', '0.04%', 252),
#  ('Iraq', 'Asia', 'Irbil', '2.10%', 253),
#  ('Philippines', 'Asia', 'Valenzuela', '0.64%', 254),
#  ('China', 'Asia', 'Baoding', '0.04%', 255),
#  ('Indonesia', 'Asia', 'Banjarmasin', '0.23%', 256),
#  ('Saudi Arabia', 'Asia', 'al-Dammam', '2.23%', 257),
#  ('China', 'Asia', 'Hunjiang', '0.04%', 258),
#  ('South Korea', 'Asia', 'Chang-won', '1.03%', 259),
#  ('Japan', 'Asia', 'Amagasaki', '0.38%', 260),
#  ('India', 'Asia', 'Mysore', '0.05%', 261),
#  ('India', 'Asia', 'Aligarh', '0.05%', 262),
#  ('Turkey', 'Asia', 'Diyarbakir', '0.72%', 263),
#  ('Turkey', 'Asia', 'Kayseri', '0.71%', 264),
#  ('Japan', 'Asia', 'Himeji', '0.37%', 265),
#  ('Japan', 'Asia', 'Shizuoka', '0.37%', 266),
#  ('China', 'Asia', 'Xinxiang', '0.04%', 267),
#  ('Philippines', 'Asia', 'Las Piñas', '0.62%', 268),
#  ('India', 'Asia', 'Guntur', '0.05%', 269),
#  ('Philippines', 'Asia', 'Antipolo', '0.62%', 270),
#  ('Turkey', 'Asia', 'Eskisehir', '0.71%', 271),
#  ('Japan', 'Asia', 'Urawa', '0.37%', 272),
#  ('Philippines', 'Asia', 'Taguig', '0.62%', 273),
#  ('Japan', 'Asia', 'Matsuyama', '0.37%', 274),
#  ('Philippines', 'Asia', 'Cagayan de Oro', '0.61%', 275),
#  ('Japan', 'Asia', 'Matsudo', '0.36%', 276),
#  ('India', 'Asia', 'Jamshedpur', '0.05%', 277),
#  ('China', 'Asia', 'Huangshi', '0.04%', 278),
#  ('Japan', 'Asia', 'Kanazawa', '0.36%', 279),
#  ('Pakistan', 'Asia', 'Sargodha', '0.29%', 280),
#  ('China', 'Asia', 'Haikou', '0.04%', 281),
#  ('India', 'Asia', 'Ghaziabad', '0.04%', 282),
#  ('Japan', 'Asia', 'Kawaguchi', '0.36%', 283),
#  ('China', 'Asia', 'Yantai', '0.04%', 284),
#  ('Philippines', 'Asia', 'Parañaque', '0.59%', 285),
#  ('China', 'Asia', 'Bengbu', '0.04%', 286),
#  ('India', 'Asia', 'Warangal', '0.04%', 287),
#  ('Philippines', 'Asia', 'Makati', '0.59%', 288),
#  ('China', 'Asia', 'Xiangtan', '0.03%', 289),
#  ('Japan', 'Asia', 'Ichikawa', '0.35%', 290),
#  ('Japan', 'Asia', 'Omiya', '0.35%', 291),
#  ('South Korea', 'Asia', 'Masan', '0.94%', 292),
#  ('Japan', 'Asia', 'Utsunomiya', '0.35%', 293),
#  ('India', 'Asia', 'Raipur', '0.04%', 294),
#  ('Indonesia', 'Asia', 'Pekan Baru', '0.21%', 295),
#  ('Macao', 'Asia', 'Macao', '92.49%', 296),
#  ('Kazakstan', 'Asia', 'Qaraghandy', '2.69%', 297),
#  ('Iran', 'Asia', 'Urmia', '0.64%', 298),
#  ('Indonesia', 'Asia', 'Denpasar', '0.21%', 299),
#  ('Japan', 'Asia', 'Oita', '0.34%', 300),
#  ('Japan', 'Asia', 'Nagasaki', '0.34%', 301),
#  ('Japan', 'Asia', 'Yokosuka', '0.34%', 302),
#  ('India', 'Asia', 'Moradabad', '0.04%', 303),
#  ('Philippines', 'Asia', 'Bacolod', '0.56%', 304),
#  ('China', 'Asia', 'Weifang', '0.03%', 305),
#  ('India', 'Asia', 'Durgapur', '0.04%', 306),
#  ('China', 'Asia', 'Wuhu', '0.03%', 307),
#  ('China', 'Asia', 'Pingxiang', '0.03%', 308),
#  ('Japan', 'Asia', 'Kurashiki', '0.34%', 309),
#  ('China', 'Asia', 'Yingkou', '0.03%', 310),
#  ('India', 'Asia', 'Amravati', '0.04%', 311),
#  ('China', 'Asia', 'Anyang', '0.03%', 312),
#  ('India', 'Asia', 'Calicut (Kozhikode)', '0.04%', 313),
#  ('Iran', 'Asia', 'Zahedan', '0.62%', 314),
#  ('Indonesia', 'Asia', 'Yogyakarta', '0.20%', 315),
#  ('Iraq', 'Asia', 'Kirkuk', '1.81%', 316),
#  ('Iran', 'Asia', 'Rasht', '0.62%', 317),
#  ('Pakistan', 'Asia', 'Sialkot', '0.27%', 318),
#  ('India', 'Asia', 'Bikaner', '0.04%', 319),
#  ('Saudi Arabia', 'Asia', 'al-Taif', '1.93%', 320),
#  ('China', 'Asia', 'Panzhihua', '0.03%', 321),
#  ('Philippines', 'Asia', 'General Santos', '0.54%', 322),
#  ('India', 'Asia', 'Bhubaneswar', '0.04%', 323),
#  ('China', 'Asia', 'Pingdingshan', '0.03%', 324),
#  ('China', 'Asia', 'Xiangfan', '0.03%', 325),
#  ('China', 'Asia', 'Zhuzhou', '0.03%', 326),
#  ('Indonesia', 'Asia', 'Pontianak', '0.19%', 327),
#  ('China', 'Asia', 'Jiaozuo', '0.03%', 328),
#  ('Japan', 'Asia', 'Gifu', '0.32%', 329),
#  ('India', 'Asia', 'Kolhapur', '0.04%', 330),
#  ('Iraq', 'Asia', 'Basra', '1.76%', 331),
#  ('Turkey', 'Asia', 'Sanliurfa', '0.61%', 332),
#  ('India', 'Asia', 'Kataka (Cuttack)', '0.04%', 333),
#  ('Pakistan', 'Asia', 'Bahawalpur', '0.26%', 334),
#  ('Japan', 'Asia', 'Hirakata', '0.32%', 335),
#  ('India', 'Asia', 'Ajmer', '0.04%', 336),
#  ('India', 'Asia', 'Bhavnagar', '0.04%', 337),
#  ('China', 'Asia', 'Wenzhou', '0.03%', 338),
#  ('Iran', 'Asia', 'Hamadan', '0.59%', 339),
#  ('China', 'Asia', 'Zhangjiang', '0.03%', 340),
#  ('Indonesia', 'Asia', 'Samarinda', '0.19%', 341),
#  ('United Arab Emirates', 'Asia', 'Abu Dhabi', '16.33%', 342),
#  ('Yemen', 'Asia', 'Aden', '2.20%', 343),
#  ('Japan', 'Asia', 'Nishinomiya', '0.31%', 344),
#  ('Japan', 'Asia', 'Toyonaka', '0.31%', 345),
#  ('China', 'Asia', 'Zigong', '0.03%', 346),
#  ('Taiwan', 'Asia', 'Chungho', '1.76%', 347),
#  ('Japan', 'Asia', 'Wakayama', '0.31%', 348),
#  ('Philippines', 'Asia', 'Marikina', '0.51%', 349),
#  ('Jordan', 'Asia', 'al-Zarqa', '7.67%', 350),
#  ('India', 'Asia', 'Tiruchirapalli', '0.04%', 351),
#  ('India', 'Asia', 'Bhilai', '0.04%', 352),
#  ('China', 'Asia', 'Shuangyashan', '0.03%', 353),
#  ('Taiwan', 'Asia', 'Keelung (Chilung)', '1.73%', 354),
#  ('Indonesia', 'Asia', 'Jambi', '0.18%', 354),
#  ('Iran', 'Asia', 'Kerman', '0.57%', 356),
#  ('Malaysia', 'Asia', 'Ipoh', '1.72%', 357),
#  ('Vietnam', 'Asia', 'Da Nang', '0.48%', 358),
#  ('China', 'Asia', 'Zaozhuang', '0.03%', 359),
#  ('Iran', 'Asia', 'Arak', '0.56%', 360),
#  ('Taiwan', 'Asia', 'Sanchung', '1.71%', 361),
#  ('Philippines', 'Asia', 'Dasmariñas', '0.50%', 362),
#  ('Philippines', 'Asia', 'Muntinlupa', '0.50%', 363),
#  ('India', 'Asia', 'Bhiwandi', '0.04%', 364),
#  ('China', 'Asia', 'Yakeshi', '0.03%', 365),
#  ('Japan', 'Asia', 'Fukuyama', '0.30%', 366),
#  ('India', 'Asia', 'Saharanpur', '0.04%', 367),
#  ('Japan', 'Asia', 'Fujisawa', '0.29%', 368),
#  ('China', 'Asia', 'Yichang', '0.03%', 369),
#  ('Uzbekistan', 'Asia', 'Namangan', '1.52%', 370),
#  ('India', 'Asia', 'Ulhasnagar', '0.04%', 371),
#  ('China', 'Asia', 'Zhenjiang', '0.03%', 372),
#  ('India', 'Asia', 'Salem', '0.04%', 373),
#  ('China', 'Asia', 'Huaibei', '0.03%', 374),
#  ('Philippines', 'Asia', 'Iloilo', '0.48%', 375),
#  ('Indonesia', 'Asia', 'Depok', '0.17%', 376),
#  ('Taiwan', 'Asia', 'Hsinchuang', '1.64%', 377),
#  ('China', 'Asia', 'Qinhuangdao', '0.03%', 378),
#  ('Japan', 'Asia', 'Asahikawa', '0.29%', 379),
#  ('Japan', 'Asia', 'Machida', '0.29%', 380),
#  ('China', 'Asia', 'Guilin', '0.03%', 381),
#  ('Iraq', 'Asia', 'al-Sulaymaniya', '1.58%', 382),
#  ('China', 'Asia', 'Liupanshui', '0.03%', 383),
#  ('Japan', 'Asia', 'Nara', '0.29%', 384),
#  ('China', 'Asia', 'Panjin', '0.03%', 385),
#  ('China', 'Asia', 'Yangquan', '0.03%', 386),
#  ('India', 'Asia', 'Ujjain', '0.04%', 387),
#  ('Taiwan', 'Asia', 'Hsinchu', '1.63%', 388),
#  ('Uzbekistan', 'Asia', 'Samarkand', '1.49%', 389),
#  ('Japan', 'Asia', 'Takatsuki', '0.29%', 390),
#  ('Japan', 'Asia', 'Iwaki', '0.29%', 391),
#  ('Japan', 'Asia', 'Nagano', '0.29%', 392),
#  ('Kazakstan', 'Asia', 'Shymkent', '2.22%', 393),
#  ('Japan', 'Asia', 'Toyohashi', '0.28%', 394),
#  ('China', 'Asia', 'Jinxi', '0.03%', 395),
#  ('Qatar', 'Asia', 'Doha', '59.27%', 396),
#  ('Philippines', 'Asia', 'Pasay', '0.47%', 397),
#  ('China', 'Asia', 'Liaoyuan', '0.03%', 398),
#  ('China', 'Asia', 'Lianyungang', '0.03%', 399),
#  ('Palestine', 'Asia', 'Gaza', '11.40%', 400),
#  ('China', 'Asia', 'Xianyang', '0.03%', 401),
#  ('South Korea', 'Asia', 'Kwangmyong', '0.75%', 402),
#  ('China', 'Asia', 'Tai´an', '0.03%', 403),
#  ('China', 'Asia', 'Chifeng', '0.03%', 404),
#  ('China', 'Asia', 'Shaoguan', '0.03%', 405),
#  ('Israel', 'Asia', 'Tel Aviv-Jaffa', '5.60%', 406),
#  ('Japan', 'Asia', 'Toyota', '0.27%', 407),
#  ('Japan', 'Asia', 'Suita', '0.27%', 408),
#  ('Indonesia', 'Asia', 'Cimahi', '0.16%', 409),
#  ('Syria', 'Asia', 'Hama', '2.13%', 410),
#  ('China', 'Asia', 'Nantong', '0.03%', 411),
#  ('India', 'Asia', 'Malegaon', '0.03%', 412),
#  ('India', 'Asia', 'Jamnagar', '0.03%', 413),
#  ('China', 'Asia', 'Leshan', '0.03%', 414),
#  ('Iran', 'Asia', 'Ardebil', '0.50%', 415),
#  ('Turkey', 'Asia', 'Samsun', '0.51%', 416),
#  ('Philippines', 'Asia', 'Malabon', '0.45%', 417),
#  ('Indonesia', 'Asia', 'Balikpapan', '0.16%', 418),
#  ('China', 'Asia', 'Baoji', '0.03%', 419),
#  ('India', 'Asia', 'Bokaro Steel City', '0.03%', 420),
#  ('Japan', 'Asia', 'Takamatsu', '0.26%', 421),
#  ('Indonesia', 'Asia', 'Manado', '0.16%', 422),
#  ('Japan', 'Asia', 'Koriyama', '0.26%', 423),
#  ('Turkey', 'Asia', 'Malatya', '0.50%', 424),
#  ('South Korea', 'Asia', 'Chonan', '0.71%', 425),
#  ('Kazakstan', 'Asia', 'Taraz', '2.03%', 426),
#  ('South Korea', 'Asia', 'Chinju', '0.70%', 427),
#  ('Pakistan', 'Asia', 'Sukkur', '0.21%', 428),
#  ('Japan', 'Asia', 'Okazaki', '0.26%', 429),
#  ('Malaysia', 'Asia', 'Johor Baharu', '1.48%', 430),
#  ('India', 'Asia', 'Akola', '0.03%', 431),
#  ('Japan', 'Asia', 'Kawagoe', '0.26%', 432),
#  ('Iran', 'Asia', 'Yazd', '0.48%', 433),
#  ('India', 'Asia', 'Belgaum', '0.03%', 434),
#  ('North Korea', 'Asia', 'Sinuiju', '1.36%', 435),
#  ('Japan', 'Asia', 'Tokorozawa', '0.26%', 436),
#  ('Japan', 'Asia', 'Toyama', '0.26%', 437),
#  ('India', 'Asia', 'Rajahmundry', '0.03%', 438),
#  ('China', 'Asia', 'Linyi', '0.03%', 439),
#  ('Japan', 'Asia', 'Kochi', '0.26%', 440),
#  ('China', 'Asia', 'Tonghua', '0.03%', 441),
#  ('South Korea', 'Asia', 'Iksan', '0.69%', 442),
#  ('Japan', 'Asia', 'Kashiwa', '0.25%', 443),
#  ('United Arab Emirates', 'Asia', 'Sharja', '13.11%', 444),
#  ('Taiwan', 'Asia', 'Chungli', '1.43%', 445),
#  ('Uzbekistan', 'Asia', 'Andijon', '1.31%', 446),
#  ('Taiwan', 'Asia', 'Fengshan', '1.43%', 447),
#  ('Yemen', 'Asia', 'Taizz', '1.75%', 448),
#  ('China', 'Asia', 'Siping', '0.02%', 449),
#  ('China', 'Asia', 'Changzhi', '0.02%', 450),
#  ('India', 'Asia', 'Nellore', '0.03%', 451),
#  ('Taiwan', 'Asia', 'Taoyuan', '1.42%', 452),
#  ('Philippines', 'Asia', 'San José del Monte', '0.42%', 453),
#  ('China', 'Asia', 'Tengzhou', '0.02%', 454),
#  ('Japan', 'Asia', 'Akita', '0.25%', 455),
#  ('China', 'Asia', 'Chaozhou', '0.02%', 456),
#  ('South Korea', 'Asia', 'Pyongtaek', '0.67%', 457),
#  ('China', 'Asia', 'Yangzhou', '0.02%', 458),
#  ('South Korea', 'Asia', 'Kumi', '0.66%', 459),
#  ('Kazakstan', 'Asia', 'Astana', '1.92%', 460),
#  ('Kazakstan', 'Asia', 'Öskemen', '1.92%', 461),
#  ('Iraq', 'Asia', 'al-Najaf', '1.34%', 462),
#  ('China', 'Asia', 'Dongwan', '0.02%', 463),
#  ('India', 'Asia', 'Udaipur', '0.03%', 464),
#  ('Myanmar', 'Asia', 'Moulmein (Mawlamyine)', '0.68%', 465),
#  ('India', 'Asia', 'New Bombay', '0.03%', 466),
#  ('Indonesia', 'Asia', 'Mataram', '0.14%', 467),
#  ('Philippines', 'Asia', 'Bacoor', '0.40%', 468),
#  ('China', 'Asia', 'Ma´anshan', '0.02%', 469),
#  ('India', 'Asia', 'Bhatpara', '0.03%', 470),
#  ('India', 'Asia', 'Gulbarga', '0.03%', 471),
#  ('Japan', 'Asia', 'Miyazaki', '0.24%', 472),
#  ('China', 'Asia', 'Foshan', '0.02%', 473),
#  ('China', 'Asia', 'Yueyang', '0.02%', 474),
#  ('China', 'Asia', 'Xingtai', '0.02%', 475),
#  ('Indonesia', 'Asia', 'Pekalongan', '0.14%', 476),
#  ('Japan', 'Asia', 'Koshigaya', '0.24%', 477),
#  ('India', 'Asia', 'New Delhi', '0.03%', 478),
#  ('China', 'Asia', 'Changde', '0.02%', 479),
#  ('India', 'Asia', 'Jhansi', '0.03%', 480),
#  ('Kazakstan', 'Asia', 'Pavlodar', '1.85%', 481),
#  ('North Korea', 'Asia', 'Wonsan', '1.25%', 482),
#  ('Japan', 'Asia', 'Naha', '0.24%', 483),
#  ('China', 'Asia', 'Shihezi', '0.02%', 484),
#  ('Azerbaijan', 'Asia', 'Gäncä', '3.87%', 485),
#  ('Yemen', 'Asia', 'Hodeida', '1.65%', 486),
#  ('China', 'Asia', 'Yancheng', '0.02%', 487),
#  ('Iraq', 'Asia', 'Karbala', '1.28%', 488),
#  ('Japan', 'Asia', 'Aomori', '0.23%', 489),
#  ('Japan', 'Asia', 'Hakodate', '0.23%', 490),
#  ('Bangladesh', 'Asia', 'Rajshahi', '0.23%', 491),
#  ('Saudi Arabia', 'Asia', 'Tabuk', '1.35%', 492),
#  ('Japan', 'Asia', 'Akashi', '0.23%', 493),
#  ('Pakistan', 'Asia', 'Jhang', '0.19%', 494),
#  ('Thailand', 'Asia', 'Nonthaburi', '0.48%', 495),
#  ('India', 'Asia', 'Gaya', '0.03%', 496),
#  ('China', 'Asia', 'Jiujiang', '0.02%', 497),
#  ('Iran', 'Asia', 'Qazvin', '0.43%', 498),
#  ('Indonesia', 'Asia', 'Tegal', '0.14%', 499),
#  ('Japan', 'Asia', 'Yokkaichi', '0.23%', 500),
#  ('Japan', 'Asia', 'Fukushima', '0.23%', 501),
#  ('Japan', 'Asia', 'Morioka', '0.23%', 502),
#  ('Iran', 'Asia', 'Zanjan', '0.42%', 503),
#  ('Indonesia', 'Asia', 'Bogor', '0.13%', 504),
#  ('Philippines', 'Asia', 'Iligan', '0.38%', 505),
#  ('Japan', 'Asia', 'Maebashi', '0.22%', 506),
#  ('Azerbaijan', 'Asia', 'Sumqayit', '3.66%', 507),
#  ('Japan', 'Asia', 'Kasugai', '0.22%', 508),
#  ('Vietnam', 'Asia', 'Biên Hoa', '0.35%', 509),
#  ('Japan', 'Asia', 'Otsu', '0.22%', 510),
#  ('China', 'Asia', 'Dongying', '0.02%', 511),
#  ('China', 'Asia', 'Shashi', '0.02%', 512),
#  ('China', 'Asia', 'Xintai', '0.02%', 513),
#  ('China', 'Asia', 'Jingdezhen', '0.02%', 514),
#  ('Philippines', 'Asia', 'Calamba', '0.37%', 515),
#  ('China', 'Asia', 'Tongchuan', '0.02%', 516),
#  ('India', 'Asia', 'Kakinada', '0.03%', 517),
#  ('Japan', 'Asia', 'Ichihara', '0.22%', 518),
#  ('China', 'Asia', 'Zhongshan', '0.02%', 519),
#  ('Philippines', 'Asia', 'Mandaluyong', '0.37%', 520),
#  ('India', 'Asia', 'Dhule (Dhulia)', '0.03%', 521),
#  ('Iran', 'Asia', 'Sanandaj', '0.41%', 522),
#  ('Japan', 'Asia', 'Yao', '0.22%', 523),
#  ('South Korea', 'Asia', 'Uijongbu', '0.59%', 524),
#  ('India', 'Asia', 'Panihati', '0.03%', 525),
#  ('India', 'Asia', 'Nanded (Nander)', '0.03%', 526),
#  ('China', 'Asia', 'Shiyan', '0.02%', 527),
#  ('Iran', 'Asia', 'Bandar-e-Abbas', '0.40%', 528),
#  ('India', 'Asia', 'Mangalore', '0.03%', 529),
#  ('South Korea', 'Asia', 'Kyongju', '0.58%', 530),
#  ('North Korea', 'Asia', 'Phyongsong', '1.14%', 531),
#  ('Iran', 'Asia', 'Khorramabad', '0.40%', 532),
#  ('Pakistan', 'Asia', 'Sheikhupura', '0.17%', 533),
#  ('Japan', 'Asia', 'Ichinomiya', '0.21%', 534),
#  ('Indonesia', 'Asia', 'Ciputat', '0.13%', 535),
#  ('Pakistan', 'Asia', 'Larkana', '0.17%', 536),
#  ('India', 'Asia', 'Dehra Dun', '0.03%', 537),
#  ('Japan', 'Asia', 'Tokushima', '0.21%', 538),
#  ('Kazakstan', 'Asia', 'Semey', '1.66%', 539),
#  ('Iraq', 'Asia', 'al-Hilla', '1.16%', 540),
#  ('Philippines', 'Asia', 'Butuan', '0.35%', 541),
#  ('India', 'Asia', 'Kamarhati', '0.03%', 542),
#  ('South Korea', 'Asia', 'Kunsan', '0.57%', 543),
#  ('Japan', 'Asia', 'Kakogawa', '0.21%', 544),
#  ('India', 'Asia', 'Davangere', '0.03%', 545),
#  ('Iraq', 'Asia', 'al-Nasiriya', '1.15%', 546),
#  ('Israel', 'Asia', 'Haifa', '4.27%', 547),
#  ('China', 'Asia', 'Tieli', '0.02%', 548),
#  ('Iran', 'Asia', 'Eslamshahr', '0.39%', 549),
#  ('China', 'Asia', 'Jining', '0.02%', 550),
#  ('Taiwan', 'Asia', 'Chiayi', '1.19%', 551),
#  ('Syria', 'Asia', 'Latakia', '1.64%', 552),
#  ('Turkey', 'Asia', 'Gebze', '0.40%', 553),
#  ('China', 'Asia', 'Wuhai', '0.02%', 554),
#  ('Philippines', 'Asia', 'Angeles', '0.35%', 555),
#  ('Taiwan', 'Asia', 'Hsintien', '1.18%', 556),
#  ('Indonesia', 'Asia', 'Pondokgede', '0.12%', 557),
#  ('China', 'Asia', 'Mianyang', '0.02%', 558),
#  ('China', 'Asia', 'Luzhou', '0.02%', 559),
#  ('Philippines', 'Asia', 'Tarlac', '0.35%', 560),
#  ('India', 'Asia', 'Asansol', '0.03%', 561),
#  ('China', 'Asia', 'Zunyi', '0.02%', 562),
#  ('Japan', 'Asia', 'Ibaraki', '0.21%', 563),
#  ('Philippines', 'Asia', 'Mandaue', '0.34%', 564),
#  ('South Korea', 'Asia', 'Cheju', '0.55%', 565),
#  ('China', 'Asia', 'Shizuishan', '0.02%', 566),
#  ('Japan', 'Asia', 'Neyagawa', '0.20%', 567),
#  ('Japan', 'Asia', 'Shimonoseki', '0.20%', 568),
#  ('South Korea', 'Asia', 'Kimhae', '0.55%', 569),
#  ('China', 'Asia', 'Neijiang', '0.02%', 570),
#  ('Japan', 'Asia', 'Yamagata', '0.20%', 571),
#  ('China', 'Asia', 'Tongliao', '0.02%', 572),
#  ('China', 'Asia', 'Tieling', '0.02%', 573),
#  ('Japan', 'Asia', 'Fukui', '0.20%', 574),
#  ('Indonesia', 'Asia', 'Cirebon', '0.12%', 575),
#  ('Malaysia', 'Asia', 'Petaling Jaya', '1.14%', 576),
#  ('Japan', 'Asia', 'Hiratsuka', '0.20%', 577),
#  ('North Korea', 'Asia', 'Sariwon', '1.06%', 578),
#  ('Turkey', 'Asia', 'Denizli', '0.38%', 579),
#  ('Indonesia', 'Asia', 'Kediri', '0.12%', 580),
#  ('India', 'Asia', 'Bhagalpur', '0.02%', 581),
#  ('Kazakstan', 'Asia', 'Aqtöbe', '1.56%', 582),
#  ('Philippines', 'Asia', 'Baguio', '0.33%', 583),
#  ('China', 'Asia', 'Wafangdian', '0.02%', 584),
#  ('China', 'Asia', 'Anqing', '0.02%', 585),
#  ('Pakistan', 'Asia', 'Gujrat', '0.16%', 586),
#  ('Indonesia', 'Asia', 'Ambon', '0.12%', 587),
#  ('South Korea', 'Asia', 'Sunchon', '0.53%', 588),
#  ('Saudi Arabia', 'Asia', 'Burayda', '1.15%', 589),
#  ('Philippines', 'Asia', 'Batangas', '0.33%', 590),
#  ('South Korea', 'Asia', 'Mokpo', '0.53%', 591),
#  ('China', 'Asia', 'Shaoyang', '0.02%', 592),
#  ('China', 'Asia', 'Laiwu', '0.02%', 593),
#  ('China', 'Asia', 'Chengde', '0.02%', 594),
#  ('Turkey', 'Asia', 'Sivas', '0.37%', 595),
#  ('Japan', 'Asia', 'Mito', '0.19%', 596),
#  ('Turkey', 'Asia', 'Erzurum', '0.37%', 597),
#  ('Turkey', 'Asia', 'Tarsus', '0.37%', 598),
#  ('Turkey', 'Asia', 'Kahramanmaras', '0.37%', 599),
#  ('India', 'Asia', 'Bellary', '0.02%', 600),
#  ('India', 'Asia', 'Barddhaman (Burdwan)', '0.02%', 601),
#  ('China', 'Asia', 'Tianshui', '0.02%', 602),
#  ('Pakistan', 'Asia', 'Mardan', '0.16%', 603),
#  ('Japan', 'Asia', 'Sasebo', '0.19%', 604),
#  ('India', 'Asia', 'Rampur', '0.02%', 605),
#  ('Malaysia', 'Asia', 'Kelang', '1.09%', 606),
#  ('China', 'Asia', 'Nanyang', '0.02%', 607),
#  ('Japan', 'Asia', 'Hachinohe', '0.19%', 608),
#  ('China', 'Asia', 'Cangzhou', '0.02%', 609),
#  ('South Korea', 'Asia', 'Yong-in', '0.52%', 610),
#  ('Philippines', 'Asia', 'Cainta', '0.32%', 611),
#  ('India', 'Asia', 'Jalgaon', '0.02%', 612),
#  ('Pakistan', 'Asia', 'Kasur', '0.15%', 613),
#  ('India', 'Asia', 'Muzaffarpur', '0.02%', 614),
#  ('India', 'Asia', 'Nizamabad', '0.02%', 615),
#  ('China', 'Asia', 'Yibin', '0.02%', 616),
#  ('Georgia', 'Asia', 'Kutaisi', '4.85%', 617),
#  ('India', 'Asia', 'Muzaffarnagar', '0.02%', 618),
#  ('Lebanon', 'Asia', 'Tripoli', '7.31%', 619),
#  ('China', 'Asia', 'Huaiyin', '0.02%', 620),
#  ('Japan', 'Asia', 'Takasaki', '0.19%', 621),
#  ('Japan', 'Asia', 'Shimizu', '0.19%', 622),
#  ('India', 'Asia', 'Patiala', '0.02%', 623),
#  ('India', 'Asia', 'Shahjahanpur', '0.02%', 624),
#  ('Afghanistan', 'Asia', 'Qandahar', '1.05%', 625),
#  ('South Korea', 'Asia', 'Wonju', '0.51%', 626),
#  ('Uzbekistan', 'Asia', 'Buhoro', '0.97%', 627),
#  ('India', 'Asia', 'Kurnool', '0.02%', 628),
#  ('India', 'Asia', 'Tiruppur (Tirupper)', '0.02%', 629),
#  ('Japan', 'Asia', 'Kurume', '0.19%', 630),
#  ('South Korea', 'Asia', 'Kunpo', '0.50%', 631),
#  ('China', 'Asia', 'Dunhua', '0.02%', 632),
#  ('South Korea', 'Asia', 'Chunchon', '0.50%', 633),
#  ('India', 'Asia', 'Rohtak', '0.02%', 634),
#  ...]

# %% [markdown]
# ### 3.3
#
# rubric={accuracy:2}

# %% [markdown]
# Suppose that we'd like to only choose the most populated city in each continent. The problem is, it's not possible to use a window function in the `WHERE` clause. But don't worry, it's not the end of the world!
#
# Using your query in Exercise [3.2](#3.2), write a common table expression (CTE) to retrieve rows associated with the most populated cities of each continent. In each row, your query should only return the city name, along with the name of the country and continent where it's located.

# %%
# %%sql
#
# WITH RankedCities AS (
#     SELECT
#         c.name AS country,
#         c.continent,
#         ci.name AS city,
#         ci.population,
#         RANK() OVER (PARTITION BY c.continent ORDER BY ci.population DESC) AS rank_in_continent
#     FROM
#         country c
#     JOIN
#         city ci
#     ON
#         c.code = ci.countrycode
#     WHERE
#         c.population IS NOT NULL AND ci.population IS NOT NULL
# )
# SELECT
#     country, continent, city
# FROM
#     RankedCities
# WHERE
#     rank_in_continent = 1
# ORDER BY
#     continent;
# Out:
#  * postgresql://postgres:***@localhost:5432/world
# 6 rows affected.
# [('Egypt', 'Africa', 'Cairo'),
#  ('India', 'Asia', 'Mumbai (Bombay)'),
#  ('Russian Federation', 'Europe', 'Moscow'),
#  ('Mexico', 'North America', 'Ciudad de México'),
#  ('Australia', 'Oceania', 'Sydney'),
#  ('Brazil', 'South America', 'São Paulo')]
